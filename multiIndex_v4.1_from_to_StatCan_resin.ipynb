# %%
import pandas as pd
import numpy as np

# %%
#import raw Statistics Canada physical flow account for plastic material, by resin, 
#from .csv, release date: 2024-03-18
data_raw_StatCan_resin = pd.read_csv('38100151.csv',sep=',')

# %%
data_raw_StatCan_resin
# Out:
#       REF_DATE     GEO           DGUID  \
# 0         2012  Canada  2021A000011124
# 1         2012  Canada  2021A000011124
# 2         2012  Canada  2021A000011124
# 3         2012  Canada  2021A000011124
# 4         2012  Canada  2021A000011124
# ...        ...     ...             ...
# 3026      2020  Canada  2021A000011124
# 3027      2020  Canada  2021A000011124
# 3028      2020  Canada  2021A000011124
# 3029      2020  Canada  2021A000011124
# 3030      2020  Canada  2021A000011124
#
#                                                Variable  \
# 0             Plastic in domestically produced products
# 1             Plastic in domestically produced products
# 2             Plastic in domestically produced products
# 3             Plastic in domestically produced products
# 4             Plastic in domestically produced products
# ...                                                 ...
# 3026             Total disposed plastic waste and scrap
# 3027             Total disposed plastic waste and scrap
# 3028  Disposed plastic waste and scrap sent to landf...
# 3029  Disposed plastic waste and scrap sent for inci...
# 3030  Net trade (imports less exports) of disposed p...
#
#                                         Resin     UOM  UOM_ID SCALAR_FACTOR  \
# 0                           Total, all resins  Tonnes     287         units
# 1     Polyethylene terephthalate (PET) resins  Tonnes     287         units
# 2        Other thermoplastic polyester resins  Tonnes     287         units
# 3             Low-density polyethylene resins  Tonnes     287         units
# 4      Linear low-density polyethylene resins  Tonnes     287         units
# ...                                       ...     ...     ...           ...
# 3026        Thermosetting polyurethane resins  Tonnes     287         units
# 3027               Other thermosetting resins  Tonnes     287         units
# 3028                        Total, all resins  Tonnes     287         units
# 3029                        Total, all resins  Tonnes     287         units
# 3030                        Total, all resins  Tonnes     287         units
#
#       SCALAR_ID       VECTOR COORDINATE      VALUE STATUS  SYMBOL  TERMINATED  \
# 0             0  v1331404607      1.1.1  3731732.0    NaN     NaN         NaN
# 1             0  v1331404608      1.1.2   377731.0    NaN     NaN         NaN
# 2             0  v1331404609      1.1.3    84982.0    NaN     NaN         NaN
# 3             0  v1331404610      1.1.4   257294.0    NaN     NaN         NaN
# 4             0  v1331404611      1.1.5   177033.0    NaN     NaN         NaN
# ...         ...          ...        ...        ...    ...     ...         ...
# 3026          0  v1331404891    1.15.19    26100.0    NaN     NaN         NaN
# 3027          0  v1331408587    1.15.20    38071.0    NaN     NaN         NaN
# 3028          0  v1331404892     1.16.1  3916862.0    NaN     NaN         NaN
# 3029          0  v1331404911     1.17.1   107577.0    NaN     NaN         NaN
# 3030          0  v1581130242     1.18.1  -496166.0    NaN     NaN         NaN
#
#       DECIMALS
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 3026         0
# 3027         0
# 3028         0
# 3029         0
# 3030         0
#
# [3031 rows x 16 columns]

# %%
#create DataFrame from raw data
df_StatCan_resin=pd.DataFrame(data=data_raw_StatCan_resin)
df_StatCan_resin
# Out:
#       REF_DATE     GEO           DGUID  \
# 0         2012  Canada  2021A000011124
# 1         2012  Canada  2021A000011124
# 2         2012  Canada  2021A000011124
# 3         2012  Canada  2021A000011124
# 4         2012  Canada  2021A000011124
# ...        ...     ...             ...
# 3026      2020  Canada  2021A000011124
# 3027      2020  Canada  2021A000011124
# 3028      2020  Canada  2021A000011124
# 3029      2020  Canada  2021A000011124
# 3030      2020  Canada  2021A000011124
#
#                                                Variable  \
# 0             Plastic in domestically produced products
# 1             Plastic in domestically produced products
# 2             Plastic in domestically produced products
# 3             Plastic in domestically produced products
# 4             Plastic in domestically produced products
# ...                                                 ...
# 3026             Total disposed plastic waste and scrap
# 3027             Total disposed plastic waste and scrap
# 3028  Disposed plastic waste and scrap sent to landf...
# 3029  Disposed plastic waste and scrap sent for inci...
# 3030  Net trade (imports less exports) of disposed p...
#
#                                         Resin     UOM  UOM_ID SCALAR_FACTOR  \
# 0                           Total, all resins  Tonnes     287         units
# 1     Polyethylene terephthalate (PET) resins  Tonnes     287         units
# 2        Other thermoplastic polyester resins  Tonnes     287         units
# 3             Low-density polyethylene resins  Tonnes     287         units
# 4      Linear low-density polyethylene resins  Tonnes     287         units
# ...                                       ...     ...     ...           ...
# 3026        Thermosetting polyurethane resins  Tonnes     287         units
# 3027               Other thermosetting resins  Tonnes     287         units
# 3028                        Total, all resins  Tonnes     287         units
# 3029                        Total, all resins  Tonnes     287         units
# 3030                        Total, all resins  Tonnes     287         units
#
#       SCALAR_ID       VECTOR COORDINATE      VALUE STATUS  SYMBOL  TERMINATED  \
# 0             0  v1331404607      1.1.1  3731732.0    NaN     NaN         NaN
# 1             0  v1331404608      1.1.2   377731.0    NaN     NaN         NaN
# 2             0  v1331404609      1.1.3    84982.0    NaN     NaN         NaN
# 3             0  v1331404610      1.1.4   257294.0    NaN     NaN         NaN
# 4             0  v1331404611      1.1.5   177033.0    NaN     NaN         NaN
# ...         ...          ...        ...        ...    ...     ...         ...
# 3026          0  v1331404891    1.15.19    26100.0    NaN     NaN         NaN
# 3027          0  v1331408587    1.15.20    38071.0    NaN     NaN         NaN
# 3028          0  v1331404892     1.16.1  3916862.0    NaN     NaN         NaN
# 3029          0  v1331404911     1.17.1   107577.0    NaN     NaN         NaN
# 3030          0  v1581130242     1.18.1  -496166.0    NaN     NaN         NaN
#
#       DECIMALS
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 3026         0
# 3027         0
# 3028         0
# 3029         0
# 3030         0
#
# [3031 rows x 16 columns]

# %%
#remove unnecessary columns
df_StatCan_resin=pd.DataFrame(df_StatCan_resin, columns=['REF_DATE','GEO','Variable','Resin',
                                                       'UOM','COORDINATE','VALUE'])
df_StatCan_resin
# Out:
#       REF_DATE     GEO                                           Variable  \
# 0         2012  Canada          Plastic in domestically produced products
# 1         2012  Canada          Plastic in domestically produced products
# 2         2012  Canada          Plastic in domestically produced products
# 3         2012  Canada          Plastic in domestically produced products
# 4         2012  Canada          Plastic in domestically produced products
# ...        ...     ...                                                ...
# 3026      2020  Canada             Total disposed plastic waste and scrap
# 3027      2020  Canada             Total disposed plastic waste and scrap
# 3028      2020  Canada  Disposed plastic waste and scrap sent to landf...
# 3029      2020  Canada  Disposed plastic waste and scrap sent for inci...
# 3030      2020  Canada  Net trade (imports less exports) of disposed p...
#
#                                         Resin     UOM COORDINATE      VALUE
# 0                           Total, all resins  Tonnes      1.1.1  3731732.0
# 1     Polyethylene terephthalate (PET) resins  Tonnes      1.1.2   377731.0
# 2        Other thermoplastic polyester resins  Tonnes      1.1.3    84982.0
# 3             Low-density polyethylene resins  Tonnes      1.1.4   257294.0
# 4      Linear low-density polyethylene resins  Tonnes      1.1.5   177033.0
# ...                                       ...     ...        ...        ...
# 3026        Thermosetting polyurethane resins  Tonnes    1.15.19    26100.0
# 3027               Other thermosetting resins  Tonnes    1.15.20    38071.0
# 3028                        Total, all resins  Tonnes     1.16.1  3916862.0
# 3029                        Total, all resins  Tonnes     1.17.1   107577.0
# 3030                        Total, all resins  Tonnes     1.18.1  -496166.0
#
# [3031 rows x 7 columns]

# %%
#arrange as multi-index of year (REF_DATE), geography (GEO), flow (Variable), and Resin.
#keep unit (UOM), coordinate and value as columns
#'COORDINATE':GEO.Variable.Resin
df_StatCan_resin_multiind=df_StatCan_resin.set_index(['REF_DATE','GEO','Variable','Resin'],inplace=False)
df_StatCan_resin_multiind
# Out:
#                                                                                                                UOM  \
# REF_DATE GEO    Variable                                           Resin
# 2012     Canada Plastic in domestically produced products          Total, all resins                        Tonnes
#                                                                    Polyethylene terephthalate (PET) resins  Tonnes
#                                                                    Other thermoplastic polyester resins     Tonnes
#                                                                    Low-density polyethylene resins          Tonnes
#                                                                    Linear low-density polyethylene resins   Tonnes
# ...                                                                                                            ...
# 2020     Canada Total disposed plastic waste and scrap             Thermosetting polyurethane resins        Tonnes
#                                                                    Other thermosetting resins               Tonnes
#                 Disposed plastic waste and scrap sent to landfi... Total, all resins                        Tonnes
#                 Disposed plastic waste and scrap sent for incin... Total, all resins                        Tonnes
#                 Net trade (imports less exports) of disposed pl... Total, all resins                        Tonnes
#
#                                                                                                            COORDINATE  \
# REF_DATE GEO    Variable                                           Resin
# 2012     Canada Plastic in domestically produced products          Total, all resins                            1.1.1
#                                                                    Polyethylene terephthalate (PET) resins      1.1.2
#                                                                    Other thermoplastic polyester resins         1.1.3
#                                                                    Low-density polyethylene resins              1.1.4
#                                                                    Linear low-density polyethylene resins       1.1.5
# ...                                                                                                               ...
# 2020     Canada Total disposed plastic waste and scrap             Thermosetting polyurethane resins          1.15.19
#                                                                    Other thermosetting resins                 1.15.20
#                 Disposed plastic waste and scrap sent to landfi... Total, all resins                           1.16.1
#                 Disposed plastic waste and scrap sent for incin... Total, all resins                           1.17.1
#                 Net trade (imports less exports) of disposed pl... Total, all resins                           1.18.1
#
#                                                                                                                 VALUE
# REF_DATE GEO    Variable                                           Resin
# 2012     Canada Plastic in domestically produced products          Total, all resins                        3731732.0
#                                                                    Polyethylene terephthalate (PET) resins   377731.0
#                                                                    Other thermoplastic polyester resins       84982.0
#                                                                    Low-density polyethylene resins           257294.0
#                                                                    Linear low-density polyethylene resins    177033.0
# ...                                                                                                               ...
# 2020     Canada Total disposed plastic waste and scrap             Thermosetting polyurethane resins          26100.0
#                                                                    Other thermosetting resins                 38071.0
#                 Disposed plastic waste and scrap sent to landfi... Total, all resins                        3916862.0
#                 Disposed plastic waste and scrap sent for incin... Total, all resins                         107577.0
#                 Net trade (imports less exports) of disposed pl... Total, all resins                        -496166.0
#
# [3031 rows x 3 columns]

# %%
#df_StatCan_prod_multiind
#add zero columns for from and to for now
#n_rows = len(df_StatCan_prod_multiind)
#df_StatCan_prod_multiind['From']=pd.Series([0] * n_rows)
#df_StatCan_prod_multiind['To']=pd.Series([0] * n_rows)
#df_StatCan_prod_multiind

# %%
#reset index
#regular_df_StatCan_prod = df_StatCan_prod_multiind.reset_index()
#regular_df_StatCan_prod

# %%
resin_data_2020_CA=df_StatCan_resin_multiind.loc['2020','Canada']
resin_data_2020_CA
# Out:
#                                                                                                UOM  \
# Variable                                           Resin
# Plastic in domestically produced products          Total, all resins                        Tonnes
#                                                    Polyethylene terephthalate (PET) resins  Tonnes
#                                                    Other thermoplastic polyester resins     Tonnes
#                                                    Low-density polyethylene resins          Tonnes
#                                                    Linear low-density polyethylene resins   Tonnes
# ...                                                                                            ...
# Total disposed plastic waste and scrap             Thermosetting polyurethane resins        Tonnes
#                                                    Other thermosetting resins               Tonnes
# Disposed plastic waste and scrap sent to landfi... Total, all resins                        Tonnes
# Disposed plastic waste and scrap sent for incin... Total, all resins                        Tonnes
# Net trade (imports less exports) of disposed pl... Total, all resins                        Tonnes
#
#                                                                                            COORDINATE  \
# Variable                                           Resin
# Plastic in domestically produced products          Total, all resins                            1.1.1
#                                                    Polyethylene terephthalate (PET) resins      1.1.2
#                                                    Other thermoplastic polyester resins         1.1.3
#                                                    Low-density polyethylene resins              1.1.4
#                                                    Linear low-density polyethylene resins       1.1.5
# ...                                                                                               ...
# Total disposed plastic waste and scrap             Thermosetting polyurethane resins          1.15.19
#                                                    Other thermosetting resins                 1.15.20
# Disposed plastic waste and scrap sent to landfi... Total, all resins                           1.16.1
# Disposed plastic waste and scrap sent for incin... Total, all resins                           1.17.1
# Net trade (imports less exports) of disposed pl... Total, all resins                           1.18.1
#
#                                                                                                 VALUE
# Variable                                           Resin
# Plastic in domestically produced products          Total, all resins                        4474733.0
#                                                    Polyethylene terephthalate (PET) resins   597458.0
#                                                    Other thermoplastic polyester resins       89175.0
#                                                    Low-density polyethylene resins           321013.0
#                                                    Linear low-density polyethylene resins    225756.0
# ...                                                                                               ...
# Total disposed plastic waste and scrap             Thermosetting polyurethane resins          26100.0
#                                                    Other thermosetting resins                 38071.0
# Disposed plastic waste and scrap sent to landfi... Total, all resins                        3916862.0
# Disposed plastic waste and scrap sent for incin... Total, all resins                         107577.0
# Net trade (imports less exports) of disposed pl... Total, all resins                        -496166.0
#
# [303 rows x 3 columns]

# %%
#import Variabl matching with From and To, #same as for StatCan product category
#compiled 2024-05-06
data_flowmatch_StatCan_prod = pd.read_csv('38100150_flow_from-to_matching.csv',sep=',')
#remove unnecessary columns
data_flowmatch_StatCan_prod=pd.DataFrame(data_flowmatch_StatCan_prod, columns=['Variable','From','To'])
data_flowmatch_StatCan_prod
# Out:
#                                              Variable  \
# 0           Plastic in domestically produced products
# 1   Net trade (imports less exports) of newly prod...
# 2   Plastic in products produced for Canadian cons...
# 3   Net stock of plastic in products that remain i...
# 4                 Total discarded plastic in products
# 5     Plastic leaked permanently into the environment
# 6   Collected plastic sent directly for disposal o...
# 7   Diverted plastic waste and scrap sent for mate...
# 8   Disposed plastic waste and scrap not diverted ...
# 9   Sorted and baled plastic waste and scrap sent ...
# 10  Residual plastic waste and scrap sent for disp...
# 11  Net trade (imports less exports) of sorted and...
# 12  Recycled plastic pellets and flakes ready for ...
# 13  Residual plastic waste and scrap sent for disp...
# 14             Total disposed plastic waste and scrap
# 15  Disposed plastic waste and scrap sent to landf...
# 16  Disposed plastic waste and scrap sent for inci...
# 17  Net trade (imports less exports) of disposed p...
#
#                          From                                  To
# 0      CA domestic production                      CA consumption
# 1   Net trade of new products                      CA consumption
# 2                         NaN                                 NaN
# 3              CA consumption           Net in-use stock addition
# 4              CA consumption            Total discarded plastics
# 5    Total discarded plastics               Leak into environment
# 6    Total discarded plastics                          Collection
# 7                  Collection                   Material recovery
# 8                  Collection             Total disposed plastics
# 9           Material recovery                           Recycling
# 10          Material recovery             Total disposed plastics
# 11          Material recovery             Net trade baled plastic
# 12                  Recycling                 Secondary feedstock
# 13                  Recycling             Total disposed plastics
# 14                        NaN                                 NaN
# 15    Total disposed plastics            Landfill or incineration
# 16    Total disposed plastics  Incineration (WtE) or gasification
# 17    Total disposed plastics         Net trade disposed plastics

# %%
#convert data_flowmatch_StatCan_prod into dictionary to match From and To in df_StatCan_prod_multiind:
#df_dict_flowmatch=data_flowmatch_StatCan_prod.to_dict(orient='records')
#df_dict_flowmatch

# %%
#import Variabl matching with From and To, 
#compiled 2024-05-06
#data_flowmatch_test = pd.read_csv('38100150_flow_empty.csv',sep=',')
#remove unnecessary columns
#data_flowmatch_test=pd.DataFrame(data_flowmatch_test, columns=['Variable','From','To'])
#data_flowmatch_test

# %%
#merge data frames
#reset index
regular_df_StatCan_resin = df_StatCan_resin_multiind.reset_index()
merged_df_StatCan_resin = pd.merge(regular_df_StatCan_resin, data_flowmatch_StatCan_prod, on='Variable', how='outer',
                          validate='many_to_many')
merged_df_StatCan_resin
# Out:
#       REF_DATE     GEO                                           Variable  \
# 0         2012  Canada          Plastic in domestically produced products
# 1         2012  Canada          Plastic in domestically produced products
# 2         2012  Canada          Plastic in domestically produced products
# 3         2012  Canada          Plastic in domestically produced products
# 4         2012  Canada          Plastic in domestically produced products
# ...        ...     ...                                                ...
# 3026      2016  Canada  Net trade (imports less exports) of disposed p...
# 3027      2017  Canada  Net trade (imports less exports) of disposed p...
# 3028      2018  Canada  Net trade (imports less exports) of disposed p...
# 3029      2019  Canada  Net trade (imports less exports) of disposed p...
# 3030      2020  Canada  Net trade (imports less exports) of disposed p...
#
#                                         Resin     UOM COORDINATE      VALUE  \
# 0                           Total, all resins  Tonnes      1.1.1  3731732.0
# 1     Polyethylene terephthalate (PET) resins  Tonnes      1.1.2   377731.0
# 2        Other thermoplastic polyester resins  Tonnes      1.1.3    84982.0
# 3             Low-density polyethylene resins  Tonnes      1.1.4   257294.0
# 4      Linear low-density polyethylene resins  Tonnes      1.1.5   177033.0
# ...                                       ...     ...        ...        ...
# 3026                        Total, all resins  Tonnes     1.18.1  -512944.0
# 3027                        Total, all resins  Tonnes     1.18.1  -591042.0
# 3028                        Total, all resins  Tonnes     1.18.1  -545656.0
# 3029                        Total, all resins  Tonnes     1.18.1  -512513.0
# 3030                        Total, all resins  Tonnes     1.18.1  -496166.0
#
#                          From                           To
# 0      CA domestic production               CA consumption
# 1      CA domestic production               CA consumption
# 2      CA domestic production               CA consumption
# 3      CA domestic production               CA consumption
# 4      CA domestic production               CA consumption
# ...                       ...                          ...
# 3026  Total disposed plastics  Net trade disposed plastics
# 3027  Total disposed plastics  Net trade disposed plastics
# 3028  Total disposed plastics  Net trade disposed plastics
# 3029  Total disposed plastics  Net trade disposed plastics
# 3030  Total disposed plastics  Net trade disposed plastics
#
# [3031 rows x 9 columns]

# %%
#recover multi-index
df_StatCan_resin_multiind=merged_df_StatCan_resin.set_index(['REF_DATE','GEO','Variable','Resin'],inplace=False)
df_StatCan_resin_multiind
#save df to Excel
df_StatCan_resin_multiind.to_excel('38100151_df.xlsx')

# %%
#select 2020 data for all of Canada
df_StatCan_resin_2020_CA=df_StatCan_resin_multiind.loc[2020,'Canada',:,:]
df_StatCan_resin_2020_CA
# Out:
#                                                                                                UOM  \
# Variable                                           Resin
# Plastic in domestically produced products          Total, all resins                        Tonnes
#                                                    Polyethylene terephthalate (PET) resins  Tonnes
#                                                    Other thermoplastic polyester resins     Tonnes
#                                                    Low-density polyethylene resins          Tonnes
#                                                    Linear low-density polyethylene resins   Tonnes
# ...                                                                                            ...
# Total disposed plastic waste and scrap             Thermosetting polyurethane resins        Tonnes
#                                                    Other thermosetting resins               Tonnes
# Disposed plastic waste and scrap sent to landfi... Total, all resins                        Tonnes
# Disposed plastic waste and scrap sent for incin... Total, all resins                        Tonnes
# Net trade (imports less exports) of disposed pl... Total, all resins                        Tonnes
#
#                                                                                            COORDINATE  \
# Variable                                           Resin
# Plastic in domestically produced products          Total, all resins                            1.1.1
#                                                    Polyethylene terephthalate (PET) resins      1.1.2
#                                                    Other thermoplastic polyester resins         1.1.3
#                                                    Low-density polyethylene resins              1.1.4
#                                                    Linear low-density polyethylene resins       1.1.5
# ...                                                                                               ...
# Total disposed plastic waste and scrap             Thermosetting polyurethane resins          1.15.19
#                                                    Other thermosetting resins                 1.15.20
# Disposed plastic waste and scrap sent to landfi... Total, all resins                           1.16.1
# Disposed plastic waste and scrap sent for incin... Total, all resins                           1.17.1
# Net trade (imports less exports) of disposed pl... Total, all resins                           1.18.1
#
#                                                                                                 VALUE  \
# Variable                                           Resin
# Plastic in domestically produced products          Total, all resins                        4474733.0
#                                                    Polyethylene terephthalate (PET) resins   597458.0
#                                                    Other thermoplastic polyester resins       89175.0
#                                                    Low-density polyethylene resins           321013.0
#                                                    Linear low-density polyethylene resins    225756.0
# ...                                                                                               ...
# Total disposed plastic waste and scrap             Thermosetting polyurethane resins          26100.0
#                                                    Other thermosetting resins                 38071.0
# Disposed plastic waste and scrap sent to landfi... Total, all resins                        3916862.0
# Disposed plastic waste and scrap sent for incin... Total, all resins                         107577.0
# Net trade (imports less exports) of disposed pl... Total, all resins                        -496166.0
#
#                                                                                                                From  \
# Variable                                           Resin
# Plastic in domestically produced products          Total, all resins                         CA domestic production
#                                                    Polyethylene terephthalate (PET) resins   CA domestic production
#                                                    Other thermoplastic polyester resins      CA domestic production
#                                                    Low-density polyethylene resins           CA domestic production
#                                                    Linear low-density polyethylene resins    CA domestic production
# ...                                                                                                             ...
# Total disposed plastic waste and scrap             Thermosetting polyurethane resins                            NaN
#                                                    Other thermosetting resins                                   NaN
# Disposed plastic waste and scrap sent to landfi... Total, all resins                        Total disposed plastics
# Disposed plastic waste and scrap sent for incin... Total, all resins                        Total disposed plastics
# Net trade (imports less exports) of disposed pl... Total, all resins                        Total disposed plastics
#
#                                                                                                                             To
# Variable                                           Resin
# Plastic in domestically produced products          Total, all resins                                            CA consumption
#                                                    Polyethylene terephthalate (PET) resins                      CA consumption
#                                                    Other thermoplastic polyester resins                         CA consumption
#                                                    Low-density polyethylene resins                              CA consumption
#                                                    Linear low-density polyethylene resins                       CA consumption
# ...                                                                                                                        ...
# Total disposed plastic waste and scrap             Thermosetting polyurethane resins                                       NaN
#                                                    Other thermosetting resins                                              NaN
# Disposed plastic waste and scrap sent to landfi... Total, all resins                                  Landfill or incineration
# Disposed plastic waste and scrap sent for incin... Total, all resins                        Incineration (WtE) or gasification
# Net trade (imports less exports) of disposed pl... Total, all resins                               Net trade disposed plastics
#
# [303 rows x 5 columns]

# %%
#hierarchy introduction not needed for StatCan resin dataset (only 'Total, all resins') includes everything else
#and can be excluded later

#import hierarchy of Product category, 
#compiled 2024-05-06
#data_hierarchy_StatCan_prod = pd.read_csv('38100150_product_category_hierarchy.csv',sep=',')
#data_hierarchy_StatCan_prod

# %%
#select 2020 data for all of Canada
#merged_prod_data_2020_CA_Total=df_StatCan_prod_multiind.loc[2020,'Canada',:,'Total, all product categories']
#merged_prod_data_2020_CA_Total

# %%
#rest index
df_StatCan_resin_2020_CA= df_StatCan_resin_2020_CA.reset_index()
#save filtered df to Excel or csv
#merged_prod_data_2020_CA.to_excel('38100150_df_2020_CA.xlsx') #only for multiIndex dfs?
df_StatCan_resin_2020_CA.to_csv('38100151_df_2020_CA.csv', sep=',')
