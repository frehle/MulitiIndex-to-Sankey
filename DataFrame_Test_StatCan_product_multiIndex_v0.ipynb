# %%
import pandas as pd
import numpy as np

# %%
#import raw Statistics Canada physical flow account for plastic material, by product category, 
#from .csv, release date: 2024-03-18
data_raw_StatCan_prod = pd.read_csv('38100150.csv',sep=',')

# %%
data_raw_StatCan_prod
# Out:
#        REF_DATE                                   GEO           DGUID  \
# 0          2012                                Canada  2021A000011124
# 1          2012                                Canada  2021A000011124
# 2          2012                                Canada  2021A000011124
# 3          2012                                Canada  2021A000011124
# 4          2012                                Canada  2021A000011124
# ...         ...                                   ...             ...
# 17402      2020  Canadian territorial enclaves abroad             NaN
# 17403      2020  Canadian territorial enclaves abroad             NaN
# 17404      2020  Canadian territorial enclaves abroad             NaN
# 17405      2020  Canadian territorial enclaves abroad             NaN
# 17406      2020  Canadian territorial enclaves abroad             NaN
#
#                                                 Variable  \
# 0              Plastic in domestically produced products
# 1              Plastic in domestically produced products
# 2              Plastic in domestically produced products
# 3              Plastic in domestically produced products
# 4              Plastic in domestically produced products
# ...                                                  ...
# 17402  Collected plastic sent directly for disposal o...
# 17403  Collected plastic sent directly for disposal o...
# 17404  Collected plastic sent directly for disposal o...
# 17405  Collected plastic sent directly for disposal o...
# 17406  Collected plastic sent directly for disposal o...
#
#                           Product category     UOM  UOM_ID SCALAR_FACTOR  \
# 0            Total, all product categories  Tonnes     287         units
# 1                   Construction materials  Tonnes     287         units
# 2      Electrical and electronic equipment  Tonnes     287         units
# 3                              Electronics  Tonnes     287         units
# 4                         Major appliances  Tonnes     287         units
# ...                                    ...     ...     ...           ...
# 17402                            Packaging  Tonnes     287         units
# 17403                     Agriculture film  Tonnes     287         units
# 17404                             Textiles  Tonnes     287         units
# 17405                             Vehicles  Tonnes     287         units
# 17406                       Other products  Tonnes     287         units
#
#        SCALAR_ID       VECTOR COORDINATE      VALUE STATUS  SYMBOL  \
# 0              0  v1331406638      1.1.1  3731732.0    NaN     NaN
# 1              0  v1331406639      1.1.2  1124918.0    NaN     NaN
# 2              0  v1331406640      1.1.3   182043.0    NaN     NaN
# 3              0  v1331406641      1.1.4    19262.0    NaN     NaN
# 4              0  v1331406642      1.1.5    40266.0    NaN     NaN
# ...          ...          ...        ...        ...    ...     ...
# 17402          0  v1331408504     15.7.7      896.0    NaN     NaN
# 17403          0  v1331408505    15.7.12        0.0    NaN     NaN
# 17404          0  v1331408506    15.7.13      332.0    NaN     NaN
# 17405          0  v1331408507    15.7.14       62.0    NaN     NaN
# 17406          0  v1331408508    15.7.15      621.0    NaN     NaN
#
#        TERMINATED  DECIMALS
# 0             NaN         0
# 1             NaN         0
# 2             NaN         0
# 3             NaN         0
# 4             NaN         0
# ...           ...       ...
# 17402         NaN         0
# 17403         NaN         0
# 17404         NaN         0
# 17405         NaN         0
# 17406         NaN         0
#
# [17407 rows x 16 columns]

# %%
#create DataFrame from raw data
df_StatCan_prod=pd.DataFrame(data=data_raw_StatCan_prod)
df_StatCan_prod
# Out:
#        REF_DATE                                   GEO           DGUID  \
# 0          2012                                Canada  2021A000011124
# 1          2012                                Canada  2021A000011124
# 2          2012                                Canada  2021A000011124
# 3          2012                                Canada  2021A000011124
# 4          2012                                Canada  2021A000011124
# ...         ...                                   ...             ...
# 17402      2020  Canadian territorial enclaves abroad             NaN
# 17403      2020  Canadian territorial enclaves abroad             NaN
# 17404      2020  Canadian territorial enclaves abroad             NaN
# 17405      2020  Canadian territorial enclaves abroad             NaN
# 17406      2020  Canadian territorial enclaves abroad             NaN
#
#                                                 Variable  \
# 0              Plastic in domestically produced products
# 1              Plastic in domestically produced products
# 2              Plastic in domestically produced products
# 3              Plastic in domestically produced products
# 4              Plastic in domestically produced products
# ...                                                  ...
# 17402  Collected plastic sent directly for disposal o...
# 17403  Collected plastic sent directly for disposal o...
# 17404  Collected plastic sent directly for disposal o...
# 17405  Collected plastic sent directly for disposal o...
# 17406  Collected plastic sent directly for disposal o...
#
#                           Product category     UOM  UOM_ID SCALAR_FACTOR  \
# 0            Total, all product categories  Tonnes     287         units
# 1                   Construction materials  Tonnes     287         units
# 2      Electrical and electronic equipment  Tonnes     287         units
# 3                              Electronics  Tonnes     287         units
# 4                         Major appliances  Tonnes     287         units
# ...                                    ...     ...     ...           ...
# 17402                            Packaging  Tonnes     287         units
# 17403                     Agriculture film  Tonnes     287         units
# 17404                             Textiles  Tonnes     287         units
# 17405                             Vehicles  Tonnes     287         units
# 17406                       Other products  Tonnes     287         units
#
#        SCALAR_ID       VECTOR COORDINATE      VALUE STATUS  SYMBOL  \
# 0              0  v1331406638      1.1.1  3731732.0    NaN     NaN
# 1              0  v1331406639      1.1.2  1124918.0    NaN     NaN
# 2              0  v1331406640      1.1.3   182043.0    NaN     NaN
# 3              0  v1331406641      1.1.4    19262.0    NaN     NaN
# 4              0  v1331406642      1.1.5    40266.0    NaN     NaN
# ...          ...          ...        ...        ...    ...     ...
# 17402          0  v1331408504     15.7.7      896.0    NaN     NaN
# 17403          0  v1331408505    15.7.12        0.0    NaN     NaN
# 17404          0  v1331408506    15.7.13      332.0    NaN     NaN
# 17405          0  v1331408507    15.7.14       62.0    NaN     NaN
# 17406          0  v1331408508    15.7.15      621.0    NaN     NaN
#
#        TERMINATED  DECIMALS
# 0             NaN         0
# 1             NaN         0
# 2             NaN         0
# 3             NaN         0
# 4             NaN         0
# ...           ...       ...
# 17402         NaN         0
# 17403         NaN         0
# 17404         NaN         0
# 17405         NaN         0
# 17406         NaN         0
#
# [17407 rows x 16 columns]

# %%
#remove unnecessary columns
df_StatCan_prod=pd.DataFrame(df_StatCan_prod, columns=['REF_DATE','GEO','Variable','Product category',
                                                       'UOM','COORDINATE','VALUE'])
df_StatCan_prod
# Out:
#        REF_DATE                                   GEO  \
# 0          2012                                Canada
# 1          2012                                Canada
# 2          2012                                Canada
# 3          2012                                Canada
# 4          2012                                Canada
# ...         ...                                   ...
# 17402      2020  Canadian territorial enclaves abroad
# 17403      2020  Canadian territorial enclaves abroad
# 17404      2020  Canadian territorial enclaves abroad
# 17405      2020  Canadian territorial enclaves abroad
# 17406      2020  Canadian territorial enclaves abroad
#
#                                                 Variable  \
# 0              Plastic in domestically produced products
# 1              Plastic in domestically produced products
# 2              Plastic in domestically produced products
# 3              Plastic in domestically produced products
# 4              Plastic in domestically produced products
# ...                                                  ...
# 17402  Collected plastic sent directly for disposal o...
# 17403  Collected plastic sent directly for disposal o...
# 17404  Collected plastic sent directly for disposal o...
# 17405  Collected plastic sent directly for disposal o...
# 17406  Collected plastic sent directly for disposal o...
#
#                           Product category     UOM COORDINATE      VALUE
# 0            Total, all product categories  Tonnes      1.1.1  3731732.0
# 1                   Construction materials  Tonnes      1.1.2  1124918.0
# 2      Electrical and electronic equipment  Tonnes      1.1.3   182043.0
# 3                              Electronics  Tonnes      1.1.4    19262.0
# 4                         Major appliances  Tonnes      1.1.5    40266.0
# ...                                    ...     ...        ...        ...
# 17402                            Packaging  Tonnes     15.7.7      896.0
# 17403                     Agriculture film  Tonnes    15.7.12        0.0
# 17404                             Textiles  Tonnes    15.7.13      332.0
# 17405                             Vehicles  Tonnes    15.7.14       62.0
# 17406                       Other products  Tonnes    15.7.15      621.0
#
# [17407 rows x 7 columns]

# %%
#arrange as multi-index of year (REF_DATE), geography (GEO), flow (Variable), and product category.
#keep unit (UOM), coordinate and value as columns
#'COORDINATE':GEO.Variable.Product category
df_StatCan_prod_multiind=df_StatCan_prod.set_index(['REF_DATE','GEO','Variable','Product category'],inplace=False)
df_StatCan_prod_multiind
# Out:
#                                                                                                                                          UOM  \
# REF_DATE GEO                                  Variable                                           Product category
# 2012     Canada                               Plastic in domestically produced products          Total, all product categories        Tonnes
#                                                                                                  Construction materials               Tonnes
#                                                                                                  Electrical and electronic equipment  Tonnes
#                                                                                                  Electronics                          Tonnes
#                                                                                                  Major appliances                     Tonnes
# ...                                                                                                                                      ...
# 2020     Canadian territorial enclaves abroad Collected plastic sent directly for disposal or... Packaging                            Tonnes
#                                                                                                  Agriculture film                     Tonnes
#                                                                                                  Textiles                             Tonnes
#                                                                                                  Vehicles                             Tonnes
#                                                                                                  Other products                       Tonnes
#
#                                                                                                                                      COORDINATE  \
# REF_DATE GEO                                  Variable                                           Product category
# 2012     Canada                               Plastic in domestically produced products          Total, all product categories            1.1.1
#                                                                                                  Construction materials                   1.1.2
#                                                                                                  Electrical and electronic equipment      1.1.3
#                                                                                                  Electronics                              1.1.4
#                                                                                                  Major appliances                         1.1.5
# ...                                                                                                                                         ...
# 2020     Canadian territorial enclaves abroad Collected plastic sent directly for disposal or... Packaging                               15.7.7
#                                                                                                  Agriculture film                       15.7.12
#                                                                                                  Textiles                               15.7.13
#                                                                                                  Vehicles                               15.7.14
#                                                                                                  Other products                         15.7.15
#
#                                                                                                                                           VALUE
# REF_DATE GEO                                  Variable                                           Product category
# 2012     Canada                               Plastic in domestically produced products          Total, all product categories        3731732.0
#                                                                                                  Construction materials               1124918.0
#                                                                                                  Electrical and electronic equipment   182043.0
#                                                                                                  Electronics                            19262.0
#                                                                                                  Major appliances                       40266.0
# ...                                                                                                                                         ...
# 2020     Canadian territorial enclaves abroad Collected plastic sent directly for disposal or... Packaging                                896.0
#                                                                                                  Agriculture film                           0.0
#                                                                                                  Textiles                                 332.0
#                                                                                                  Vehicles                                  62.0
#                                                                                                  Other products                           621.0
#
# [17407 rows x 3 columns]

# %%
df_StatCan_prod_multiind
#add zero columns for from and to for now
#n_rows = len(df_StatCan_prod_multiind)
#df_StatCan_prod_multiind['From']=pd.Series([0] * n_rows)
#df_StatCan_prod_multiind['To']=pd.Series([0] * n_rows)
#df_StatCan_prod_multiind
# Out:
#                                                                                                                                          UOM  \
# REF_DATE GEO                                  Variable                                           Product category
# 2012     Canada                               Plastic in domestically produced products          Total, all product categories        Tonnes
#                                                                                                  Construction materials               Tonnes
#                                                                                                  Electrical and electronic equipment  Tonnes
#                                                                                                  Electronics                          Tonnes
#                                                                                                  Major appliances                     Tonnes
# ...                                                                                                                                      ...
# 2020     Canadian territorial enclaves abroad Collected plastic sent directly for disposal or... Packaging                            Tonnes
#                                                                                                  Agriculture film                     Tonnes
#                                                                                                  Textiles                             Tonnes
#                                                                                                  Vehicles                             Tonnes
#                                                                                                  Other products                       Tonnes
#
#                                                                                                                                      COORDINATE  \
# REF_DATE GEO                                  Variable                                           Product category
# 2012     Canada                               Plastic in domestically produced products          Total, all product categories            1.1.1
#                                                                                                  Construction materials                   1.1.2
#                                                                                                  Electrical and electronic equipment      1.1.3
#                                                                                                  Electronics                              1.1.4
#                                                                                                  Major appliances                         1.1.5
# ...                                                                                                                                         ...
# 2020     Canadian territorial enclaves abroad Collected plastic sent directly for disposal or... Packaging                               15.7.7
#                                                                                                  Agriculture film                       15.7.12
#                                                                                                  Textiles                               15.7.13
#                                                                                                  Vehicles                               15.7.14
#                                                                                                  Other products                         15.7.15
#
#                                                                                                                                           VALUE
# REF_DATE GEO                                  Variable                                           Product category
# 2012     Canada                               Plastic in domestically produced products          Total, all product categories        3731732.0
#                                                                                                  Construction materials               1124918.0
#                                                                                                  Electrical and electronic equipment   182043.0
#                                                                                                  Electronics                            19262.0
#                                                                                                  Major appliances                       40266.0
# ...                                                                                                                                         ...
# 2020     Canadian territorial enclaves abroad Collected plastic sent directly for disposal or... Packaging                                896.0
#                                                                                                  Agriculture film                           0.0
#                                                                                                  Textiles                                 332.0
#                                                                                                  Vehicles                                  62.0
#                                                                                                  Other products                           621.0
#
# [17407 rows x 3 columns]

# %%
#reset index
#regular_df_StatCan_prod = df_StatCan_prod_multiind.reset_index()
#regular_df_StatCan_prod

# %%
prod_data_2020_CA=df_StatCan_prod_multiind.loc['2020','Canada']
prod_data_2020_CA
# Out:
# C:\Users\franz\AppData\Local\Temp\ipykernel_20492\3646695702.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   prod_data_2020_CA=df_StatCan_prod_multiind.loc['2020','Canada']
#                                                                                            UOM  \
# Variable                                           Product category
# Plastic in domestically produced products          Total, all product categories        Tonnes
#                                                    Construction materials               Tonnes
#                                                    Electrical and electronic equipment  Tonnes
#                                                    Electronics                          Tonnes
#                                                    Major appliances                     Tonnes
# ...                                                                                        ...
# Total disposed plastic waste and scrap             Vehicles                             Tonnes
#                                                    Other products                       Tonnes
# Disposed plastic waste and scrap sent to landfi... Total, all product categories        Tonnes
# Disposed plastic waste and scrap sent for incin... Total, all product categories        Tonnes
# Net trade (imports less exports) of disposed pl... Total, all product categories        Tonnes
#
#                                                                                        COORDINATE  \
# Variable                                           Product category
# Plastic in domestically produced products          Total, all product categories            1.1.1
#                                                    Construction materials                   1.1.2
#                                                    Electrical and electronic equipment      1.1.3
#                                                    Electronics                              1.1.4
#                                                    Major appliances                         1.1.5
# ...                                                                                           ...
# Total disposed plastic waste and scrap             Vehicles                               1.15.14
#                                                    Other products                         1.15.15
# Disposed plastic waste and scrap sent to landfi... Total, all product categories           1.16.1
# Disposed plastic waste and scrap sent for incin... Total, all product categories           1.17.1
# Net trade (imports less exports) of disposed pl... Total, all product categories           1.18.1
#
#                                                                                             VALUE
# Variable                                           Product category
# Plastic in domestically produced products          Total, all product categories        4474733.0
#                                                    Construction materials               1353236.0
#                                                    Electrical and electronic equipment   150005.0
#                                                    Electronics                             7621.0
#                                                    Major appliances                       10281.0
# ...                                                                                           ...
# Total disposed plastic waste and scrap             Vehicles                              721398.0
#                                                    Other products                       1225521.0
# Disposed plastic waste and scrap sent to landfi... Total, all product categories        3916862.0
# Disposed plastic waste and scrap sent for incin... Total, all product categories         107577.0
# Net trade (imports less exports) of disposed pl... Total, all product categories        -496166.0
#
# [225 rows x 3 columns]

# %%
#import Variabl matching with From and To, 
#compiled 2024-05-06
data_flowmatch_StatCan_prod = pd.read_csv('38100150_flow_from-to_matching.csv',sep=',')
#remove unnecessary columns
data_flowmatch_StatCan_prod=pd.DataFrame(data_flowmatch_StatCan_prod, columns=['Variable','From','To'])
data_flowmatch_StatCan_prod
# Out:
#                                              Variable  \
# 0           Plastic in domestically produced products
# 1   Net trade (imports less exports) of newly prod...
# 2   Plastic in products produced for Canadian cons...
# 3   Net stock of plastic in products that remain i...
# 4                 Total discarded plastic in products
# 5     Plastic leaked permanently into the environment
# 6   Collected plastic sent directly for disposal o...
# 7   Diverted plastic waste and scrap sent for mate...
# 8   Disposed plastic waste and scrap not diverted ...
# 9   Sorted and baled plastic waste and scrap sent ...
# 10  Residual plastic waste and scrap sent for disp...
# 11  Net trade (imports less exports) of sorted and...
# 12  Recycled plastic pellets and flakes ready for ...
# 13  Residual plastic waste and scrap sent for disp...
# 14             Total disposed plastic waste and scrap
# 15  Disposed plastic waste and scrap sent to landf...
# 16  Disposed plastic waste and scrap sent for inci...
# 17  Net trade (imports less exports) of disposed p...
#
#                          From                                  To
# 0      CA domestic production                      CA consumption
# 1   Net trade of new products                      CA consumption
# 2                           0                                   0
# 3              CA consumption           Net in-use stock addition
# 4              CA consumption            Total discarded plastics
# 5    Total discarded plastics               Leak into environment
# 6    Total discarded plastics                          Collection
# 7                  Collection                   Material recovery
# 8                  Collection             Total disposed plastics
# 9           Material recovery                           Recycling
# 10          Material recovery             Total disposed plastics
# 11          Material recovery             Net trade baled plastic
# 12                  Recycling                 Secondary feedstock
# 13                  Recycling             Total disposed plastics
# 14                          0                                   0
# 15    Total disposed plastics            Landfill or incineration
# 16    Total disposed plastics  Incineration (WtE) or gasification
# 17    Total disposed plastics         Net trade disposed plastics

# %%
#convert data_flowmatch_StatCan_prod into dictionary to match From and To in df_StatCan_prod_multiind:
#df_dict_flowmatch=data_flowmatch_StatCan_prod.to_dict(orient='records')
#df_dict_flowmatch
# Out:
# [{'Variable': 'Plastic in domestically produced products',
#   'From': 'CA domestic production',
#   'To': 'CA consumption'},
#  {'Variable': 'Net trade (imports less exports) of newly produced products',
#   'From': 'Net trade of new products',
#   'To': 'CA consumption'},
#  {'Variable': 'Plastic in products produced for Canadian consumption',
#   'From': '0',
#   'To': '0'},
#  {'Variable': 'Net stock of plastic in products that remain in use at the end of each year',
#   'From': 'CA consumption',
#   'To': 'Net in-use stock addition'},
#  {'Variable': 'Total discarded plastic in products',
#   'From': 'CA consumption',
#   'To': 'Total discarded plastics'},
#  {'Variable': 'Plastic leaked permanently into the environment',
#   'From': 'Total discarded plastics',
#   'To': 'Leak into environment'},
#  {'Variable': 'Collected plastic sent directly for disposal or diversion',
#   'From': 'Total discarded plastics',
#   'To': 'Collection'},
#  {'Variable': 'Diverted plastic waste and scrap sent for material recovery',
#   'From': 'Collection',
#   'To': 'Material recovery'},
#  {'Variable': 'Disposed plastic waste and scrap not diverted for material recovery',
#   'From': 'Collection',
#   'To': 'Total disposed plastics'},
#  {'Variable': 'Sorted and baled plastic waste and scrap sent for further processing',
#   'From': 'Material recovery',
#   'To': 'Recycling'},
#  {'Variable': 'Residual plastic waste and scrap sent for disposal by primary processors',
#   'From': 'Material recovery',
#   'To': 'Total disposed plastics'},
#  {'Variable': 'Net trade (imports less exports) of sorted and baled plastic waste and scrap',
#   'From': 'Material recovery',
#   'To': 'Net trade baled plastic'},
#  {'Variable': 'Recycled plastic pellets and flakes ready for use in production of new products',
#   'From': 'Recycling',
#   'To': 'Secondary feedstock'},
#  {'Variable': 'Residual plastic waste and scrap sent for disposal by final processors',
#   'From': 'Recycling',
#   'To': 'Total disposed plastics'},
#  {'Variable': 'Total disposed plastic waste and scrap',
#   'From': '0',
#   'To': '0'},
#  {'Variable': 'Disposed plastic waste and scrap sent to landfill or incinerated without energy recovery',
#   'From': 'Total disposed plastics',
#   'To': 'Landfill or incineration'},
#  {'Variable': 'Disposed plastic waste and scrap sent for incineration or gasification with energy recovery',
#   'From': 'Total disposed plastics',
#   'To': 'Incineration (WtE) or gasification'},
#  {'Variable': 'Net trade (imports less exports) of disposed plastic waste and scrap',
#   'From': 'Total disposed plastics',
#   'To': 'Net trade disposed plastics'}]

# %%
#import Variabl matching with From and To, 
#compiled 2024-05-06
data_flowmatch_test = pd.read_csv('38100150_flow_empty.csv',sep=',')
#remove unnecessary columns
data_flowmatch_test=pd.DataFrame(data_flowmatch_test, columns=['Variable','From','To'])
data_flowmatch_test
# Out:
#                                              Variable  From  To
# 0           Plastic in domestically produced products     1   0
# 1   Net trade (imports less exports) of newly prod...     1   0
# 2   Plastic in products produced for Canadian cons...     1   0
# 3   Net stock of plastic in products that remain i...     1   0
# 4                 Total discarded plastic in products     1   0
# 5     Plastic leaked permanently into the environment     1   0
# 6   Collected plastic sent directly for disposal o...     1   0
# 7   Diverted plastic waste and scrap sent for mate...     1   0
# 8   Disposed plastic waste and scrap not diverted ...     1   0
# 9   Sorted and baled plastic waste and scrap sent ...     1   0
# 10  Residual plastic waste and scrap sent for disp...     1   0
# 11  Net trade (imports less exports) of sorted and...     1   0
# 12  Recycled plastic pellets and flakes ready for ...     1   0
# 13  Residual plastic waste and scrap sent for disp...     1   0
# 14             Total disposed plastic waste and scrap     1   0
# 15  Disposed plastic waste and scrap sent to landf...     1   0
# 16  Disposed plastic waste and scrap sent for inci...     1   0
# 17  Net trade (imports less exports) of disposed p...     1   0

# %%
#merge data frames
#reset index
regular_df_StatCan_prod = df_StatCan_prod_multiind.reset_index()
merged_df_StatCan_prod = pd.merge(regular_df_StatCan_prod, data_flowmatch_StatCan_prod, on='Variable', how='outer',
                          validate='many_to_many')
merged_df_StatCan_prod
# Out:
#        REF_DATE                    GEO  \
# 0          2012                 Canada
# 1          2012                 Canada
# 2          2012                 Canada
# 3          2012                 Canada
# 4          2012                 Canada
# ...         ...                    ...
# 17402      2020                Alberta
# 17403      2020       British Columbia
# 17404      2020                  Yukon
# 17405      2020  Northwest Territories
# 17406      2020                Nunavut
#
#                                                 Variable  \
# 0              Plastic in domestically produced products
# 1              Plastic in domestically produced products
# 2              Plastic in domestically produced products
# 3              Plastic in domestically produced products
# 4              Plastic in domestically produced products
# ...                                                  ...
# 17402  Net trade (imports less exports) of disposed p...
# 17403  Net trade (imports less exports) of disposed p...
# 17404  Net trade (imports less exports) of disposed p...
# 17405  Net trade (imports less exports) of disposed p...
# 17406  Net trade (imports less exports) of disposed p...
#
#                           Product category     UOM COORDINATE      VALUE  \
# 0            Total, all product categories  Tonnes      1.1.1  3731732.0
# 1                   Construction materials  Tonnes      1.1.2  1124918.0
# 2      Electrical and electronic equipment  Tonnes      1.1.3   182043.0
# 3                              Electronics  Tonnes      1.1.4    19262.0
# 4                         Major appliances  Tonnes      1.1.5    40266.0
# ...                                    ...     ...        ...        ...
# 17402        Total, all product categories  Tonnes    10.18.1      160.0
# 17403        Total, all product categories  Tonnes    11.18.1   -70510.0
# 17404        Total, all product categories  Tonnes    12.18.1        0.0
# 17405        Total, all product categories  Tonnes    13.18.1        0.0
# 17406        Total, all product categories  Tonnes    14.18.1        0.0
#
#                           From                           To
# 0       CA domestic production               CA consumption
# 1       CA domestic production               CA consumption
# 2       CA domestic production               CA consumption
# 3       CA domestic production               CA consumption
# 4       CA domestic production               CA consumption
# ...                        ...                          ...
# 17402  Total disposed plastics  Net trade disposed plastics
# 17403  Total disposed plastics  Net trade disposed plastics
# 17404  Total disposed plastics  Net trade disposed plastics
# 17405  Total disposed plastics  Net trade disposed plastics
# 17406  Total disposed plastics  Net trade disposed plastics
#
# [17407 rows x 9 columns]

# %%
#recover multi-index
df_StatCan_prod_multiind=merged_df_StatCan_prod.set_index(['REF_DATE','GEO','Variable','Product category'],inplace=False)
df_StatCan_prod_multiind
# Out:
#                                                                                                                           UOM  \
# REF_DATE GEO                   Variable                                           Product category
# 2012     Canada                Plastic in domestically produced products          Total, all product categories        Tonnes
#                                                                                   Construction materials               Tonnes
#                                                                                   Electrical and electronic equipment  Tonnes
#                                                                                   Electronics                          Tonnes
#                                                                                   Major appliances                     Tonnes
# ...                                                                                                                       ...
# 2020     Alberta               Net trade (imports less exports) of disposed pl... Total, all product categories        Tonnes
#          British Columbia      Net trade (imports less exports) of disposed pl... Total, all product categories        Tonnes
#          Yukon                 Net trade (imports less exports) of disposed pl... Total, all product categories        Tonnes
#          Northwest Territories Net trade (imports less exports) of disposed pl... Total, all product categories        Tonnes
#          Nunavut               Net trade (imports less exports) of disposed pl... Total, all product categories        Tonnes
#
#                                                                                                                       COORDINATE  \
# REF_DATE GEO                   Variable                                           Product category
# 2012     Canada                Plastic in domestically produced products          Total, all product categories            1.1.1
#                                                                                   Construction materials                   1.1.2
#                                                                                   Electrical and electronic equipment      1.1.3
#                                                                                   Electronics                              1.1.4
#                                                                                   Major appliances                         1.1.5
# ...                                                                                                                          ...
# 2020     Alberta               Net trade (imports less exports) of disposed pl... Total, all product categories          10.18.1
#          British Columbia      Net trade (imports less exports) of disposed pl... Total, all product categories          11.18.1
#          Yukon                 Net trade (imports less exports) of disposed pl... Total, all product categories          12.18.1
#          Northwest Territories Net trade (imports less exports) of disposed pl... Total, all product categories          13.18.1
#          Nunavut               Net trade (imports less exports) of disposed pl... Total, all product categories          14.18.1
#
#                                                                                                                            VALUE  \
# REF_DATE GEO                   Variable                                           Product category
# 2012     Canada                Plastic in domestically produced products          Total, all product categories        3731732.0
#                                                                                   Construction materials               1124918.0
#                                                                                   Electrical and electronic equipment   182043.0
#                                                                                   Electronics                            19262.0
#                                                                                   Major appliances                       40266.0
# ...                                                                                                                          ...
# 2020     Alberta               Net trade (imports less exports) of disposed pl... Total, all product categories            160.0
#          British Columbia      Net trade (imports less exports) of disposed pl... Total, all product categories         -70510.0
#          Yukon                 Net trade (imports less exports) of disposed pl... Total, all product categories              0.0
#          Northwest Territories Net trade (imports less exports) of disposed pl... Total, all product categories              0.0
#          Nunavut               Net trade (imports less exports) of disposed pl... Total, all product categories              0.0
#
#                                                                                                                                           From  \
# REF_DATE GEO                   Variable                                           Product category
# 2012     Canada                Plastic in domestically produced products          Total, all product categories         CA domestic production
#                                                                                   Construction materials                CA domestic production
#                                                                                   Electrical and electronic equipment   CA domestic production
#                                                                                   Electronics                           CA domestic production
#                                                                                   Major appliances                      CA domestic production
# ...                                                                                                                                        ...
# 2020     Alberta               Net trade (imports less exports) of disposed pl... Total, all product categories        Total disposed plastics
#          British Columbia      Net trade (imports less exports) of disposed pl... Total, all product categories        Total disposed plastics
#          Yukon                 Net trade (imports less exports) of disposed pl... Total, all product categories        Total disposed plastics
#          Northwest Territories Net trade (imports less exports) of disposed pl... Total, all product categories        Total disposed plastics
#          Nunavut               Net trade (imports less exports) of disposed pl... Total, all product categories        Total disposed plastics
#
#                                                                                                                                                 To
# REF_DATE GEO                   Variable                                           Product category
# 2012     Canada                Plastic in domestically produced products          Total, all product categories                     CA consumption
#                                                                                   Construction materials                            CA consumption
#                                                                                   Electrical and electronic equipment               CA consumption
#                                                                                   Electronics                                       CA consumption
#                                                                                   Major appliances                                  CA consumption
# ...                                                                                                                                            ...
# 2020     Alberta               Net trade (imports less exports) of disposed pl... Total, all product categories        Net trade disposed plastics
#          British Columbia      Net trade (imports less exports) of disposed pl... Total, all product categories        Net trade disposed plastics
#          Yukon                 Net trade (imports less exports) of disposed pl... Total, all product categories        Net trade disposed plastics
#          Northwest Territories Net trade (imports less exports) of disposed pl... Total, all product categories        Net trade disposed plastics
#          Nunavut               Net trade (imports less exports) of disposed pl... Total, all product categories        Net trade disposed plastics
#
# [17407 rows x 5 columns]

# %%
#select 2020 data for all of Canada
merged_prod_data_2020_CA=df_StatCan_prod_multiind.loc[2020,'Canada',:,:]
merged_prod_data_2020_CA
# Out:
#                                                                                            UOM  \
# Variable                                           Product category
# Plastic in domestically produced products          Total, all product categories        Tonnes
#                                                    Construction materials               Tonnes
#                                                    Electrical and electronic equipment  Tonnes
#                                                    Electronics                          Tonnes
#                                                    Major appliances                     Tonnes
# ...                                                                                        ...
# Total disposed plastic waste and scrap             Vehicles                             Tonnes
#                                                    Other products                       Tonnes
# Disposed plastic waste and scrap sent to landfi... Total, all product categories        Tonnes
# Disposed plastic waste and scrap sent for incin... Total, all product categories        Tonnes
# Net trade (imports less exports) of disposed pl... Total, all product categories        Tonnes
#
#                                                                                        COORDINATE  \
# Variable                                           Product category
# Plastic in domestically produced products          Total, all product categories            1.1.1
#                                                    Construction materials                   1.1.2
#                                                    Electrical and electronic equipment      1.1.3
#                                                    Electronics                              1.1.4
#                                                    Major appliances                         1.1.5
# ...                                                                                           ...
# Total disposed plastic waste and scrap             Vehicles                               1.15.14
#                                                    Other products                         1.15.15
# Disposed plastic waste and scrap sent to landfi... Total, all product categories           1.16.1
# Disposed plastic waste and scrap sent for incin... Total, all product categories           1.17.1
# Net trade (imports less exports) of disposed pl... Total, all product categories           1.18.1
#
#                                                                                             VALUE  \
# Variable                                           Product category
# Plastic in domestically produced products          Total, all product categories        4474733.0
#                                                    Construction materials               1353236.0
#                                                    Electrical and electronic equipment   150005.0
#                                                    Electronics                             7621.0
#                                                    Major appliances                       10281.0
# ...                                                                                           ...
# Total disposed plastic waste and scrap             Vehicles                              721398.0
#                                                    Other products                       1225521.0
# Disposed plastic waste and scrap sent to landfi... Total, all product categories        3916862.0
# Disposed plastic waste and scrap sent for incin... Total, all product categories         107577.0
# Net trade (imports less exports) of disposed pl... Total, all product categories        -496166.0
#
#                                                                                                            From  \
# Variable                                           Product category
# Plastic in domestically produced products          Total, all product categories         CA domestic production
#                                                    Construction materials                CA domestic production
#                                                    Electrical and electronic equipment   CA domestic production
#                                                    Electronics                           CA domestic production
#                                                    Major appliances                      CA domestic production
# ...                                                                                                         ...
# Total disposed plastic waste and scrap             Vehicles                                                   0
#                                                    Other products                                             0
# Disposed plastic waste and scrap sent to landfi... Total, all product categories        Total disposed plastics
# Disposed plastic waste and scrap sent for incin... Total, all product categories        Total disposed plastics
# Net trade (imports less exports) of disposed pl... Total, all product categories        Total disposed plastics
#
#                                                                                                                         To
# Variable                                           Product category
# Plastic in domestically produced products          Total, all product categories                            CA consumption
#                                                    Construction materials                                   CA consumption
#                                                    Electrical and electronic equipment                      CA consumption
#                                                    Electronics                                              CA consumption
#                                                    Major appliances                                         CA consumption
# ...                                                                                                                    ...
# Total disposed plastic waste and scrap             Vehicles                                                              0
#                                                    Other products                                                        0
# Disposed plastic waste and scrap sent to landfi... Total, all product categories                  Landfill or incineration
# Disposed plastic waste and scrap sent for incin... Total, all product categories        Incineration (WtE) or gasification
# Net trade (imports less exports) of disposed pl... Total, all product categories               Net trade disposed plastics
#
# [225 rows x 5 columns]

# %%
#import hierarchy of Product category, 
#compiled 2024-05-06
data_hierarchy_StatCan_prod = pd.read_csv('38100150_product_category_hierarchy.csv',sep=',')
data_hierarchy_StatCan_prod
# Out:
#     Level                           Product category
# 0       1              Total, all product categories
# 1       2                     Construction materials
# 2       2        Electrical and electronic equipment
# 3       3                                Electronics
# 4       3                           Major appliances
# 5       3  Other electrical and electronic equipment
# 6       2                                  Packaging
# 7       3                                    Bottles
# 8       3                                       Film
# 9       3                           Non-bottle rigid
# 10      3                   Other packaging products
# 11      2                           Agriculture film
# 12      2                                   Textiles
# 13      2                                   Vehicles
# 14      2                             Other products
