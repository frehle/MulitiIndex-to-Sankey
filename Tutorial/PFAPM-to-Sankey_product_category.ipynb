# %%
#Script created as a light version to directly plot the Statistics Canada (StatCan)
#Physical flow accounts for plastic material (PFAPM) as a Sankey diagram

# %%
import pandas as pd
import plotly.graph_objects as go

# %% [markdown]
# Sankey of PFAPM by product category

# %%
#files used in this script:
    #38100150 (PFAPM by product category)
    #flowmatch
    #product_category_hierarchy
    #product_category_selection

# %%
#import raw StatCan PFAPM by product category, as .csv file
#https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=3810015001
#or use saved file in 'files' (38100150.csv, downloaded 2024-04-18)
data_raw_StatCan_prod = pd.read_csv("files/38100150.csv",sep=',')
data_raw_StatCan_prod
# Out:
#        REF_DATE                                   GEO           DGUID  \
# 0          2012                                Canada  2021A000011124
# 1          2012                                Canada  2021A000011124
# 2          2012                                Canada  2021A000011124
# 3          2012                                Canada  2021A000011124
# 4          2012                                Canada  2021A000011124
# ...         ...                                   ...             ...
# 17402      2020  Canadian territorial enclaves abroad             NaN
# 17403      2020  Canadian territorial enclaves abroad             NaN
# 17404      2020  Canadian territorial enclaves abroad             NaN
# 17405      2020  Canadian territorial enclaves abroad             NaN
# 17406      2020  Canadian territorial enclaves abroad             NaN
#
#                                                 Variable  \
# 0              Plastic in domestically produced products
# 1              Plastic in domestically produced products
# 2              Plastic in domestically produced products
# 3              Plastic in domestically produced products
# 4              Plastic in domestically produced products
# ...                                                  ...
# 17402  Collected plastic sent directly for disposal o...
# 17403  Collected plastic sent directly for disposal o...
# 17404  Collected plastic sent directly for disposal o...
# 17405  Collected plastic sent directly for disposal o...
# 17406  Collected plastic sent directly for disposal o...
#
#                           Product category     UOM  UOM_ID SCALAR_FACTOR  \
# 0            Total, all product categories  Tonnes     287         units
# 1                   Construction materials  Tonnes     287         units
# 2      Electrical and electronic equipment  Tonnes     287         units
# 3                              Electronics  Tonnes     287         units
# 4                         Major appliances  Tonnes     287         units
# ...                                    ...     ...     ...           ...
# 17402                            Packaging  Tonnes     287         units
# 17403                     Agriculture film  Tonnes     287         units
# 17404                             Textiles  Tonnes     287         units
# 17405                             Vehicles  Tonnes     287         units
# 17406                       Other products  Tonnes     287         units
#
#        SCALAR_ID       VECTOR COORDINATE      VALUE STATUS  SYMBOL  \
# 0              0  v1331406638      1.1.1  3731732.0    NaN     NaN
# 1              0  v1331406639      1.1.2  1124918.0    NaN     NaN
# 2              0  v1331406640      1.1.3   182043.0    NaN     NaN
# 3              0  v1331406641      1.1.4    19262.0    NaN     NaN
# 4              0  v1331406642      1.1.5    40266.0    NaN     NaN
# ...          ...          ...        ...        ...    ...     ...
# 17402          0  v1331408504     15.7.7      896.0    NaN     NaN
# 17403          0  v1331408505    15.7.12        0.0    NaN     NaN
# 17404          0  v1331408506    15.7.13      332.0    NaN     NaN
# 17405          0  v1331408507    15.7.14       62.0    NaN     NaN
# 17406          0  v1331408508    15.7.15      621.0    NaN     NaN
#
#        TERMINATED  DECIMALS
# 0             NaN         0
# 1             NaN         0
# 2             NaN         0
# 3             NaN         0
# 4             NaN         0
# ...           ...       ...
# 17402         NaN         0
# 17403         NaN         0
# 17404         NaN         0
# 17405         NaN         0
# 17406         NaN         0
#
# [17407 rows x 16 columns]

# %%
#create data frame from raw data
df_StatCan_prod=pd.DataFrame(data=data_raw_StatCan_prod)

# %%
#import variable matching: 'flowmatch' file (with 'From' and 'To' columns)
#same file for StatCan resin (compiled 2024-05-06)
data_flowmatch_StatCan_prod = pd.read_csv("files/flowmatch.csv", sep=',')
#remove unnecessary columns
data_flowmatch_StatCan_prod=pd.DataFrame(data_flowmatch_StatCan_prod, columns=['Variable','From','To'])
data_flowmatch_StatCan_prod
# Out:
#                                              Variable  \
# 0           Plastic in domestically produced products
# 1   Net trade (imports less exports) of newly prod...
# 2   Plastic in products produced for Canadian cons...
# 3   Net stock of plastic in products that remain i...
# 4                 Total discarded plastic in products
# 5     Plastic leaked permanently into the environment
# 6   Collected plastic sent directly for disposal o...
# 7   Diverted plastic waste and scrap sent for mate...
# 8   Disposed plastic waste and scrap not diverted ...
# 9   Sorted and baled plastic waste and scrap sent ...
# 10  Residual plastic waste and scrap sent for disp...
# 11  Net trade (imports less exports) of sorted and...
# 12  Recycled plastic pellets and flakes ready for ...
# 13  Residual plastic waste and scrap sent for disp...
# 14             Total disposed plastic waste and scrap
# 15  Disposed plastic waste and scrap sent to landf...
# 16  Disposed plastic waste and scrap sent for inci...
# 17  Net trade (imports less exports) of disposed p...
#
#                          From                                  To
# 0      CA domestic production                      CA consumption
# 1   Net trade of new products                      CA consumption
# 2                         NaN                                 NaN
# 3              CA consumption           Net in-use stock addition
# 4              CA consumption            Total discarded plastics
# 5    Total discarded plastics               Leak into environment
# 6    Total discarded plastics                          Collection
# 7                  Collection                   Material recovery
# 8                  Collection             Total disposed plastics
# 9           Material recovery                           Recycling
# 10          Material recovery             Total disposed plastics
# 11          Material recovery             Net trade baled plastic
# 12                  Recycling                 Secondary feedstock
# 13                  Recycling             Total disposed plastics
# 14                        NaN                                 NaN
# 15    Total disposed plastics            Landfill or incineration
# 16    Total disposed plastics  Incineration (WtE) or gasification
# 17    Total disposed plastics         Net trade disposed plastics

# %%
#merge data frames (df_StatCan_prod and data_flowmatch_StatCan_prod)
merged_df_StatCan_prod = pd.merge(df_StatCan_prod, data_flowmatch_StatCan_prod, on='Variable', how='outer', validate='many_to_many')
merged_df_StatCan_prod
# Out:
#        REF_DATE      GEO           DGUID  \
# 0          2012   Canada  2021A000011124
# 1          2012   Canada  2021A000011124
# 2          2012   Canada  2021A000011124
# 3          2012   Canada  2021A000011124
# 4          2012   Canada  2021A000011124
# ...         ...      ...             ...
# 17402      2020  Nunavut     2021A000262
# 17403      2020  Nunavut     2021A000262
# 17404      2020  Nunavut     2021A000262
# 17405      2020  Nunavut     2021A000262
# 17406      2020  Nunavut     2021A000262
#
#                                                 Variable  \
# 0      Collected plastic sent directly for disposal o...
# 1      Collected plastic sent directly for disposal o...
# 2      Collected plastic sent directly for disposal o...
# 3      Collected plastic sent directly for disposal o...
# 4      Collected plastic sent directly for disposal o...
# ...                                                  ...
# 17402             Total disposed plastic waste and scrap
# 17403             Total disposed plastic waste and scrap
# 17404             Total disposed plastic waste and scrap
# 17405             Total disposed plastic waste and scrap
# 17406             Total disposed plastic waste and scrap
#
#                           Product category     UOM  UOM_ID SCALAR_FACTOR  \
# 0            Total, all product categories  Tonnes     287         units
# 1                   Construction materials  Tonnes     287         units
# 2      Electrical and electronic equipment  Tonnes     287         units
# 3                              Electronics  Tonnes     287         units
# 4                         Major appliances  Tonnes     287         units
# ...                                    ...     ...     ...           ...
# 17402                            Packaging  Tonnes     287         units
# 17403                     Agriculture film  Tonnes     287         units
# 17404                             Textiles  Tonnes     287         units
# 17405                             Vehicles  Tonnes     287         units
# 17406                       Other products  Tonnes     287         units
#
#        SCALAR_ID       VECTOR COORDINATE      VALUE STATUS  SYMBOL  \
# 0              0  v1331406728      1.7.1  4282879.0    NaN     NaN
# 1              0  v1331406729      1.7.2   155443.0    NaN     NaN
# 2              0  v1331406730      1.7.3   396316.0    NaN     NaN
# 3              0  v1331406731      1.7.4    95677.0    NaN     NaN
# 4              0  v1331406732      1.7.5    24104.0    NaN     NaN
# ...          ...          ...        ...        ...    ...     ...
# 17402          0  v1331408448    14.15.7     1125.0    NaN     NaN
# 17403          0  v1331408449   14.15.12        0.0    NaN     NaN
# 17404          0  v1331408450   14.15.13      212.0    NaN     NaN
# 17405          0  v1331408451   14.15.14      850.0    NaN     NaN
# 17406          0  v1331408452   14.15.15     2158.0    NaN     NaN
#
#        TERMINATED  DECIMALS                      From          To
# 0             NaN         0  Total discarded plastics  Collection
# 1             NaN         0  Total discarded plastics  Collection
# 2             NaN         0  Total discarded plastics  Collection
# 3             NaN         0  Total discarded plastics  Collection
# 4             NaN         0  Total discarded plastics  Collection
# ...           ...       ...                       ...         ...
# 17402         NaN         0                       NaN         NaN
# 17403         NaN         0                       NaN         NaN
# 17404         NaN         0                       NaN         NaN
# 17405         NaN         0                       NaN         NaN
# 17406         NaN         0                       NaN         NaN
#
# [17407 rows x 18 columns]

# %%
#convert into multi-index to filter for relevant columns and rows
df_StatCan_prod_multiind=merged_df_StatCan_prod.set_index(['REF_DATE','GEO','Variable','Product category'],inplace=False)
df_StatCan_prod_multiind
# Out:
#                                                                                                                   DGUID  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories        2021A000011124
#                                                                     Construction materials               2021A000011124
#                                                                     Electrical and electronic equipment  2021A000011124
#                                                                     Electronics                          2021A000011124
#                                                                     Major appliances                     2021A000011124
# ...                                                                                                                 ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                               2021A000262
#                                                                     Agriculture film                        2021A000262
#                                                                     Textiles                                2021A000262
#                                                                     Vehicles                                2021A000262
#                                                                     Other products                          2021A000262
#
#                                                                                                             UOM  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories        Tonnes
#                                                                     Construction materials               Tonnes
#                                                                     Electrical and electronic equipment  Tonnes
#                                                                     Electronics                          Tonnes
#                                                                     Major appliances                     Tonnes
# ...                                                                                                         ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                            Tonnes
#                                                                     Agriculture film                     Tonnes
#                                                                     Textiles                             Tonnes
#                                                                     Vehicles                             Tonnes
#                                                                     Other products                       Tonnes
#
#                                                                                                          UOM_ID  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories           287
#                                                                     Construction materials                  287
#                                                                     Electrical and electronic equipment     287
#                                                                     Electronics                             287
#                                                                     Major appliances                        287
# ...                                                                                                         ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                               287
#                                                                     Agriculture film                        287
#                                                                     Textiles                                287
#                                                                     Vehicles                                287
#                                                                     Other products                          287
#
#                                                                                                         SCALAR_FACTOR  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories               units
#                                                                     Construction materials                      units
#                                                                     Electrical and electronic equipment         units
#                                                                     Electronics                                 units
#                                                                     Major appliances                            units
# ...                                                                                                               ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                                   units
#                                                                     Agriculture film                            units
#                                                                     Textiles                                    units
#                                                                     Vehicles                                    units
#                                                                     Other products                              units
#
#                                                                                                          SCALAR_ID  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories                0
#                                                                     Construction materials                       0
#                                                                     Electrical and electronic equipment          0
#                                                                     Electronics                                  0
#                                                                     Major appliances                             0
# ...                                                                                                            ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                                    0
#                                                                     Agriculture film                             0
#                                                                     Textiles                                     0
#                                                                     Vehicles                                     0
#                                                                     Other products                               0
#
#                                                                                                               VECTOR  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories        v1331406728
#                                                                     Construction materials               v1331406729
#                                                                     Electrical and electronic equipment  v1331406730
#                                                                     Electronics                          v1331406731
#                                                                     Major appliances                     v1331406732
# ...                                                                                                              ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                            v1331408448
#                                                                     Agriculture film                     v1331408449
#                                                                     Textiles                             v1331408450
#                                                                     Vehicles                             v1331408451
#                                                                     Other products                       v1331408452
#
#                                                                                                         COORDINATE  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories            1.7.1
#                                                                     Construction materials                   1.7.2
#                                                                     Electrical and electronic equipment      1.7.3
#                                                                     Electronics                              1.7.4
#                                                                     Major appliances                         1.7.5
# ...                                                                                                            ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                              14.15.7
#                                                                     Agriculture film                      14.15.12
#                                                                     Textiles                              14.15.13
#                                                                     Vehicles                              14.15.14
#                                                                     Other products                        14.15.15
#
#                                                                                                              VALUE  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories        4282879.0
#                                                                     Construction materials                155443.0
#                                                                     Electrical and electronic equipment   396316.0
#                                                                     Electronics                            95677.0
#                                                                     Major appliances                       24104.0
# ...                                                                                                            ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                               1125.0
#                                                                     Agriculture film                           0.0
#                                                                     Textiles                                 212.0
#                                                                     Vehicles                                 850.0
#                                                                     Other products                          2158.0
#
#                                                                                                         STATUS  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories          NaN
#                                                                     Construction materials                 NaN
#                                                                     Electrical and electronic equipment    NaN
#                                                                     Electronics                            NaN
#                                                                     Major appliances                       NaN
# ...                                                                                                        ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                              NaN
#                                                                     Agriculture film                       NaN
#                                                                     Textiles                               NaN
#                                                                     Vehicles                               NaN
#                                                                     Other products                         NaN
#
#                                                                                                          SYMBOL  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories           NaN
#                                                                     Construction materials                  NaN
#                                                                     Electrical and electronic equipment     NaN
#                                                                     Electronics                             NaN
#                                                                     Major appliances                        NaN
# ...                                                                                                         ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                               NaN
#                                                                     Agriculture film                        NaN
#                                                                     Textiles                                NaN
#                                                                     Vehicles                                NaN
#                                                                     Other products                          NaN
#
#                                                                                                          TERMINATED  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories               NaN
#                                                                     Construction materials                      NaN
#                                                                     Electrical and electronic equipment         NaN
#                                                                     Electronics                                 NaN
#                                                                     Major appliances                            NaN
# ...                                                                                                             ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                                   NaN
#                                                                     Agriculture film                            NaN
#                                                                     Textiles                                    NaN
#                                                                     Vehicles                                    NaN
#                                                                     Other products                              NaN
#
#                                                                                                          DECIMALS  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories               0
#                                                                     Construction materials                      0
#                                                                     Electrical and electronic equipment         0
#                                                                     Electronics                                 0
#                                                                     Major appliances                            0
# ...                                                                                                           ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                                   0
#                                                                     Agriculture film                            0
#                                                                     Textiles                                    0
#                                                                     Vehicles                                    0
#                                                                     Other products                              0
#
#                                                                                                                              From  \
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories        Total discarded plastics
#                                                                     Construction materials               Total discarded plastics
#                                                                     Electrical and electronic equipment  Total discarded plastics
#                                                                     Electronics                          Total discarded plastics
#                                                                     Major appliances                     Total discarded plastics
# ...                                                                                                                           ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                                                 NaN
#                                                                     Agriculture film                                          NaN
#                                                                     Textiles                                                  NaN
#                                                                     Vehicles                                                  NaN
#                                                                     Other products                                            NaN
#
#                                                                                                                  To
# REF_DATE GEO     Variable                                           Product category
# 2012     Canada  Collected plastic sent directly for disposal or... Total, all product categories        Collection
#                                                                     Construction materials               Collection
#                                                                     Electrical and electronic equipment  Collection
#                                                                     Electronics                          Collection
#                                                                     Major appliances                     Collection
# ...                                                                                                             ...
# 2020     Nunavut Total disposed plastic waste and scrap             Packaging                                   NaN
#                                                                     Agriculture film                            NaN
#                                                                     Textiles                                    NaN
#                                                                     Vehicles                                    NaN
#                                                                     Other products                              NaN
#
# [17407 rows x 14 columns]

# %%
#select year ("REF_DATE") and geography ("GEO") you want to plot
#here REF_DATE = 2020, and GEO = Canada
df_StatCan_prod_2020_CA = df_StatCan_prod_multiind.loc[2020,'Canada',:,:]
df_StatCan_prod_2020_CA
# Out:
#                                                                                                  DGUID  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories        2021A000011124
#                                                    Construction materials               2021A000011124
#                                                    Electrical and electronic equipment  2021A000011124
#                                                    Electronics                          2021A000011124
#                                                    Major appliances                     2021A000011124
# ...                                                                                                ...
# Total disposed plastic waste and scrap             Other packaging products             2021A000011124
#                                                    Agriculture film                     2021A000011124
#                                                    Textiles                             2021A000011124
#                                                    Vehicles                             2021A000011124
#                                                    Other products                       2021A000011124
#
#                                                                                            UOM  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories        Tonnes
#                                                    Construction materials               Tonnes
#                                                    Electrical and electronic equipment  Tonnes
#                                                    Electronics                          Tonnes
#                                                    Major appliances                     Tonnes
# ...                                                                                        ...
# Total disposed plastic waste and scrap             Other packaging products             Tonnes
#                                                    Agriculture film                     Tonnes
#                                                    Textiles                             Tonnes
#                                                    Vehicles                             Tonnes
#                                                    Other products                       Tonnes
#
#                                                                                         UOM_ID  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories           287
#                                                    Construction materials                  287
#                                                    Electrical and electronic equipment     287
#                                                    Electronics                             287
#                                                    Major appliances                        287
# ...                                                                                        ...
# Total disposed plastic waste and scrap             Other packaging products                287
#                                                    Agriculture film                        287
#                                                    Textiles                                287
#                                                    Vehicles                                287
#                                                    Other products                          287
#
#                                                                                        SCALAR_FACTOR  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories               units
#                                                    Construction materials                      units
#                                                    Electrical and electronic equipment         units
#                                                    Electronics                                 units
#                                                    Major appliances                            units
# ...                                                                                              ...
# Total disposed plastic waste and scrap             Other packaging products                    units
#                                                    Agriculture film                            units
#                                                    Textiles                                    units
#                                                    Vehicles                                    units
#                                                    Other products                              units
#
#                                                                                         SCALAR_ID  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories                0
#                                                    Construction materials                       0
#                                                    Electrical and electronic equipment          0
#                                                    Electronics                                  0
#                                                    Major appliances                             0
# ...                                                                                           ...
# Total disposed plastic waste and scrap             Other packaging products                     0
#                                                    Agriculture film                             0
#                                                    Textiles                                     0
#                                                    Vehicles                                     0
#                                                    Other products                               0
#
#                                                                                              VECTOR  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories        v1331406728
#                                                    Construction materials               v1331406729
#                                                    Electrical and electronic equipment  v1331406730
#                                                    Electronics                          v1331406731
#                                                    Major appliances                     v1331406732
# ...                                                                                             ...
# Total disposed plastic waste and scrap             Other packaging products             v1331406858
#                                                    Agriculture film                     v1331406859
#                                                    Textiles                             v1331406860
#                                                    Vehicles                             v1331406861
#                                                    Other products                       v1331406862
#
#                                                                                        COORDINATE  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories            1.7.1
#                                                    Construction materials                   1.7.2
#                                                    Electrical and electronic equipment      1.7.3
#                                                    Electronics                              1.7.4
#                                                    Major appliances                         1.7.5
# ...                                                                                           ...
# Total disposed plastic waste and scrap             Other packaging products               1.15.11
#                                                    Agriculture film                       1.15.12
#                                                    Textiles                               1.15.13
#                                                    Vehicles                               1.15.14
#                                                    Other products                         1.15.15
#
#                                                                                             VALUE  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories        4887289.0
#                                                    Construction materials                164611.0
#                                                    Electrical and electronic equipment   439203.0
#                                                    Electronics                           120034.0
#                                                    Major appliances                       25661.0
# ...                                                                                           ...
# Total disposed plastic waste and scrap             Other packaging products               89328.0
#                                                    Agriculture film                       36706.0
#                                                    Textiles                              275695.0
#                                                    Vehicles                              721398.0
#                                                    Other products                       1225521.0
#
#                                                                                        STATUS  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories          NaN
#                                                    Construction materials                 NaN
#                                                    Electrical and electronic equipment    NaN
#                                                    Electronics                            NaN
#                                                    Major appliances                       NaN
# ...                                                                                       ...
# Total disposed plastic waste and scrap             Other packaging products               NaN
#                                                    Agriculture film                       NaN
#                                                    Textiles                               NaN
#                                                    Vehicles                               NaN
#                                                    Other products                         NaN
#
#                                                                                         SYMBOL  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories           NaN
#                                                    Construction materials                  NaN
#                                                    Electrical and electronic equipment     NaN
#                                                    Electronics                             NaN
#                                                    Major appliances                        NaN
# ...                                                                                        ...
# Total disposed plastic waste and scrap             Other packaging products                NaN
#                                                    Agriculture film                        NaN
#                                                    Textiles                                NaN
#                                                    Vehicles                                NaN
#                                                    Other products                          NaN
#
#                                                                                         TERMINATED  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories               NaN
#                                                    Construction materials                      NaN
#                                                    Electrical and electronic equipment         NaN
#                                                    Electronics                                 NaN
#                                                    Major appliances                            NaN
# ...                                                                                            ...
# Total disposed plastic waste and scrap             Other packaging products                    NaN
#                                                    Agriculture film                            NaN
#                                                    Textiles                                    NaN
#                                                    Vehicles                                    NaN
#                                                    Other products                              NaN
#
#                                                                                         DECIMALS  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories               0
#                                                    Construction materials                      0
#                                                    Electrical and electronic equipment         0
#                                                    Electronics                                 0
#                                                    Major appliances                            0
# ...                                                                                          ...
# Total disposed plastic waste and scrap             Other packaging products                    0
#                                                    Agriculture film                            0
#                                                    Textiles                                    0
#                                                    Vehicles                                    0
#                                                    Other products                              0
#
#                                                                                                             From  \
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories        Total discarded plastics
#                                                    Construction materials               Total discarded plastics
#                                                    Electrical and electronic equipment  Total discarded plastics
#                                                    Electronics                          Total discarded plastics
#                                                    Major appliances                     Total discarded plastics
# ...                                                                                                          ...
# Total disposed plastic waste and scrap             Other packaging products                                  NaN
#                                                    Agriculture film                                          NaN
#                                                    Textiles                                                  NaN
#                                                    Vehicles                                                  NaN
#                                                    Other products                                            NaN
#
#                                                                                                 To
# Variable                                           Product category
# Collected plastic sent directly for disposal or... Total, all product categories        Collection
#                                                    Construction materials               Collection
#                                                    Electrical and electronic equipment  Collection
#                                                    Electronics                          Collection
#                                                    Major appliances                     Collection
# ...                                                                                            ...
# Total disposed plastic waste and scrap             Other packaging products                    NaN
#                                                    Agriculture film                            NaN
#                                                    Textiles                                    NaN
#                                                    Vehicles                                    NaN
#                                                    Other products                              NaN
#
# [225 rows x 14 columns]

# %%
#reset index of df_StatCan_prod_2020_CA
df_StatCan_prod_2020_CA = df_StatCan_prod_2020_CA.reset_index()

#turn 'VALUE' into absolute values
df_StatCan_prod_2020_CA['VALUE'] =df_StatCan_prod_2020_CA['VALUE'].apply(lambda x: abs(x))
df_StatCan_prod_2020_CA
# Out:
#                                               Variable  \
# 0    Collected plastic sent directly for disposal o...
# 1    Collected plastic sent directly for disposal o...
# 2    Collected plastic sent directly for disposal o...
# 3    Collected plastic sent directly for disposal o...
# 4    Collected plastic sent directly for disposal o...
# ..                                                 ...
# 220             Total disposed plastic waste and scrap
# 221             Total disposed plastic waste and scrap
# 222             Total disposed plastic waste and scrap
# 223             Total disposed plastic waste and scrap
# 224             Total disposed plastic waste and scrap
#
#                         Product category           DGUID     UOM  UOM_ID  \
# 0          Total, all product categories  2021A000011124  Tonnes     287
# 1                 Construction materials  2021A000011124  Tonnes     287
# 2    Electrical and electronic equipment  2021A000011124  Tonnes     287
# 3                            Electronics  2021A000011124  Tonnes     287
# 4                       Major appliances  2021A000011124  Tonnes     287
# ..                                   ...             ...     ...     ...
# 220             Other packaging products  2021A000011124  Tonnes     287
# 221                     Agriculture film  2021A000011124  Tonnes     287
# 222                             Textiles  2021A000011124  Tonnes     287
# 223                             Vehicles  2021A000011124  Tonnes     287
# 224                       Other products  2021A000011124  Tonnes     287
#
#     SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE      VALUE STATUS  \
# 0           units          0  v1331406728      1.7.1  4887289.0    NaN
# 1           units          0  v1331406729      1.7.2   164611.0    NaN
# 2           units          0  v1331406730      1.7.3   439203.0    NaN
# 3           units          0  v1331406731      1.7.4   120034.0    NaN
# 4           units          0  v1331406732      1.7.5    25661.0    NaN
# ..            ...        ...          ...        ...        ...    ...
# 220         units          0  v1331406858    1.15.11    89328.0    NaN
# 221         units          0  v1331406859    1.15.12    36706.0    NaN
# 222         units          0  v1331406860    1.15.13   275695.0    NaN
# 223         units          0  v1331406861    1.15.14   721398.0    NaN
# 224         units          0  v1331406862    1.15.15  1225521.0    NaN
#
#      SYMBOL  TERMINATED  DECIMALS                      From          To
# 0       NaN         NaN         0  Total discarded plastics  Collection
# 1       NaN         NaN         0  Total discarded plastics  Collection
# 2       NaN         NaN         0  Total discarded plastics  Collection
# 3       NaN         NaN         0  Total discarded plastics  Collection
# 4       NaN         NaN         0  Total discarded plastics  Collection
# ..      ...         ...       ...                       ...         ...
# 220     NaN         NaN         0                       NaN         NaN
# 221     NaN         NaN         0                       NaN         NaN
# 222     NaN         NaN         0                       NaN         NaN
# 223     NaN         NaN         0                       NaN         NaN
# 224     NaN         NaN         0                       NaN         NaN
#
# [225 rows x 16 columns]

# %%
#import product_category_hierarchy file (compiled 2024-05-06)
data_hierarchy_StatCan_prod = pd.read_csv("files/product_category_hierarchy.csv",sep=',')
data_hierarchy_StatCan_prod
# Out:
#     Level                           Product category
# 0       1              Total, all product categories
# 1       2                     Construction materials
# 2       2        Electrical and electronic equipment
# 3       3                                Electronics
# 4       3                           Major appliances
# 5       3  Other electrical and electronic equipment
# 6       2                                  Packaging
# 7       3                                    Bottles
# 8       3                                       Film
# 9       3                           Non-bottle rigid
# 10      3                   Other packaging products
# 11      2                           Agriculture film
# 12      2                                   Textiles
# 13      2                                   Vehicles
# 14      2                             Other products

# %%
#merge data frames: df_StatCan_prod_2020_CA and data_hierarchy_StatCan_prod
df_StatCan_prod_2020_CA = pd.merge(df_StatCan_prod_2020_CA, data_hierarchy_StatCan_prod, on='Product category', how='outer',validate='many_to_many')
df_StatCan_prod_2020_CA
# Out:
#                                               Variable  Product category  \
# 0    Collected plastic sent directly for disposal o...  Agriculture film
# 1    Disposed plastic waste and scrap not diverted ...  Agriculture film
# 2    Diverted plastic waste and scrap sent for mate...  Agriculture film
# 3    Net stock of plastic in products that remain i...  Agriculture film
# 4    Net trade (imports less exports) of newly prod...  Agriculture film
# ..                                                 ...               ...
# 220  Residual plastic waste and scrap sent for disp...          Vehicles
# 221  Residual plastic waste and scrap sent for disp...          Vehicles
# 222  Sorted and baled plastic waste and scrap sent ...          Vehicles
# 223                Total discarded plastic in products          Vehicles
# 224             Total disposed plastic waste and scrap          Vehicles
#
#               DGUID     UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  \
# 0    2021A000011124  Tonnes     287         units          0  v1331406739
# 1    2021A000011124  Tonnes     287         units          0  v1331406769
# 2    2021A000011124  Tonnes     287         units          0  v1331406754
# 3    2021A000011124  Tonnes     287         units          0  v1331406694
# 4    2021A000011124  Tonnes     287         units          0  v1331406664
# ..              ...     ...     ...           ...        ...          ...
# 220  2021A000011124  Tonnes     287         units          0  v1331406846
# 221  2021A000011124  Tonnes     287         units          0  v1331406801
# 222  2021A000011124  Tonnes     287         units          0  v1331406786
# 223  2021A000011124  Tonnes     287         units          0  v1331406711
# 224  2021A000011124  Tonnes     287         units          0  v1331406861
#
#     COORDINATE     VALUE STATUS  SYMBOL  TERMINATED  DECIMALS  \
# 0       1.7.12   43891.0    NaN     NaN         NaN         0
# 1       1.9.12   33699.0    NaN     NaN         NaN         0
# 2       1.8.12   10191.0    NaN     NaN         NaN         0
# 3       1.4.12    8863.0    NaN     NaN         NaN         0
# 4       1.2.12    7770.0    NaN     NaN         NaN         0
# ..         ...       ...    ...     ...         ...       ...
# 220    1.14.14    1114.0    NaN     NaN         NaN         0
# 221    1.11.14  720284.0    NaN     NaN         NaN         0
# 222    1.10.14    7276.0    NaN     NaN         NaN         0
# 223     1.5.14  732599.0    NaN     NaN         NaN         0
# 224    1.15.14  721398.0    NaN     NaN         NaN         0
#
#                           From                         To  Level
# 0     Total discarded plastics                 Collection      2
# 1                   Collection    Total disposed plastics      2
# 2                   Collection          Material recovery      2
# 3               CA consumption  Net in-use stock addition      2
# 4    Net trade of new products             CA consumption      2
# ..                         ...                        ...    ...
# 220                  Recycling    Total disposed plastics      2
# 221          Material recovery    Total disposed plastics      2
# 222          Material recovery                  Recycling      2
# 223             CA consumption   Total discarded plastics      2
# 224                        NaN                        NaN      2
#
# [225 rows x 17 columns]

# %%
#Set level of end-of-life flows to 'Level' = 2 (even though the data is only for 'Total, all resins')
#The end-of-life flows considered are:
    #'Disposed plastic waste and scrap sent to landfill or incinerated without energy recovery'
    #'Disposed plastic waste and scrap sent for incineration or gasification with energy recovery'
    #'Net trade (imports less exports) of disposed plastic waste and scrap'
df_StatCan_prod_2020_CA.loc[df_StatCan_prod_2020_CA['Variable'] 
== 'Disposed plastic waste and scrap sent to landfill or incinerated without energy recovery','Level']=2

df_StatCan_prod_2020_CA.loc[df_StatCan_prod_2020_CA['Variable'] 
== 'Disposed plastic waste and scrap sent for incineration or gasification with energy recovery','Level']=2

df_StatCan_prod_2020_CA.loc[df_StatCan_prod_2020_CA['Variable'] 
== 'Net trade (imports less exports) of disposed plastic waste and scrap','Level']=2
#exclude all other ('Level' = 1,3)
df_StatCan_prod_2020_CA_2 = df_StatCan_prod_2020_CA[df_StatCan_prod_2020_CA['Level']== 2]
df_StatCan_prod_2020_CA_2
# Out:
#                                               Variable  Product category  \
# 0    Collected plastic sent directly for disposal o...  Agriculture film
# 1    Disposed plastic waste and scrap not diverted ...  Agriculture film
# 2    Diverted plastic waste and scrap sent for mate...  Agriculture film
# 3    Net stock of plastic in products that remain i...  Agriculture film
# 4    Net trade (imports less exports) of newly prod...  Agriculture film
# ..                                                 ...               ...
# 220  Residual plastic waste and scrap sent for disp...          Vehicles
# 221  Residual plastic waste and scrap sent for disp...          Vehicles
# 222  Sorted and baled plastic waste and scrap sent ...          Vehicles
# 223                Total discarded plastic in products          Vehicles
# 224             Total disposed plastic waste and scrap          Vehicles
#
#               DGUID     UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  \
# 0    2021A000011124  Tonnes     287         units          0  v1331406739
# 1    2021A000011124  Tonnes     287         units          0  v1331406769
# 2    2021A000011124  Tonnes     287         units          0  v1331406754
# 3    2021A000011124  Tonnes     287         units          0  v1331406694
# 4    2021A000011124  Tonnes     287         units          0  v1331406664
# ..              ...     ...     ...           ...        ...          ...
# 220  2021A000011124  Tonnes     287         units          0  v1331406846
# 221  2021A000011124  Tonnes     287         units          0  v1331406801
# 222  2021A000011124  Tonnes     287         units          0  v1331406786
# 223  2021A000011124  Tonnes     287         units          0  v1331406711
# 224  2021A000011124  Tonnes     287         units          0  v1331406861
#
#     COORDINATE     VALUE STATUS  SYMBOL  TERMINATED  DECIMALS  \
# 0       1.7.12   43891.0    NaN     NaN         NaN         0
# 1       1.9.12   33699.0    NaN     NaN         NaN         0
# 2       1.8.12   10191.0    NaN     NaN         NaN         0
# 3       1.4.12    8863.0    NaN     NaN         NaN         0
# 4       1.2.12    7770.0    NaN     NaN         NaN         0
# ..         ...       ...    ...     ...         ...       ...
# 220    1.14.14    1114.0    NaN     NaN         NaN         0
# 221    1.11.14  720284.0    NaN     NaN         NaN         0
# 222    1.10.14    7276.0    NaN     NaN         NaN         0
# 223     1.5.14  732599.0    NaN     NaN         NaN         0
# 224    1.15.14  721398.0    NaN     NaN         NaN         0
#
#                           From                         To  Level
# 0     Total discarded plastics                 Collection      2
# 1                   Collection    Total disposed plastics      2
# 2                   Collection          Material recovery      2
# 3               CA consumption  Net in-use stock addition      2
# 4    Net trade of new products             CA consumption      2
# ..                         ...                        ...    ...
# 220                  Recycling    Total disposed plastics      2
# 221          Material recovery    Total disposed plastics      2
# 222          Material recovery                  Recycling      2
# 223             CA consumption   Total discarded plastics      2
# 224                        NaN                        NaN      2
#
# [105 rows x 17 columns]

# %%
#import product category colour selection file (product_category_selection, compiled 2024-09-13)
data_selection_StatCan_prod = pd.read_csv("files/product_category_selection.csv",sep=',')
data_selection_StatCan_prod
# Out:
#     Level                           Product category Colour_HEX  \
# 0       1              Total, all product categories    #7F7F7F
# 1       2                     Construction materials    #00A1C0
# 2       2        Electrical and electronic equipment    #FA961E
# 3       3                                Electronics    #FEE9A2
# 4       3                           Major appliances    #FEE9A2
# 5       3  Other electrical and electronic equipment    #FEE9A2
# 6       2                                  Packaging    #0BAC43
# 7       3                                    Bottles    #47F383
# 8       3                                       Film    #47F383
# 9       3                           Non-bottle rigid    #47F383
# 10      3                   Other packaging products    #47F383
# 11      2                           Agriculture film    #B91E32
# 12      2                                   Textiles    #005379
# 13      2                                   Vehicles    #FDDA64
# 14      2                             Other products    #40E0FF
#
#             Colour
# 0             grey
# 1         turqoise
# 2           orange
# 3     light-yellow
# 4     light-yellow
# 5     light-yellow
# 6            green
# 7      light-green
# 8      light-green
# 9      light-green
# 10     light-green
# 11             red
# 12        darkblue
# 13          yellow
# 14  light-turqoise

# %%
#merge data frames: df_StatCan_prod_2020_CA_2 and data_selection_StatCan_prod
df_StatCan_prod_2020_CA_2 = pd.merge(df_StatCan_prod_2020_CA_2, data_selection_StatCan_prod, on='Product category', how='outer', validate='many_to_many')
df_StatCan_prod_2020_CA_2
# Out:
#                                               Variable  Product category  \
# 0    Collected plastic sent directly for disposal o...  Agriculture film
# 1    Disposed plastic waste and scrap not diverted ...  Agriculture film
# 2    Diverted plastic waste and scrap sent for mate...  Agriculture film
# 3    Net stock of plastic in products that remain i...  Agriculture film
# 4    Net trade (imports less exports) of newly prod...  Agriculture film
# ..                                                 ...               ...
# 107  Residual plastic waste and scrap sent for disp...          Vehicles
# 108  Residual plastic waste and scrap sent for disp...          Vehicles
# 109  Sorted and baled plastic waste and scrap sent ...          Vehicles
# 110                Total discarded plastic in products          Vehicles
# 111             Total disposed plastic waste and scrap          Vehicles
#
#               DGUID     UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  \
# 0    2021A000011124  Tonnes   287.0         units        0.0  v1331406739
# 1    2021A000011124  Tonnes   287.0         units        0.0  v1331406769
# 2    2021A000011124  Tonnes   287.0         units        0.0  v1331406754
# 3    2021A000011124  Tonnes   287.0         units        0.0  v1331406694
# 4    2021A000011124  Tonnes   287.0         units        0.0  v1331406664
# ..              ...     ...     ...           ...        ...          ...
# 107  2021A000011124  Tonnes   287.0         units        0.0  v1331406846
# 108  2021A000011124  Tonnes   287.0         units        0.0  v1331406801
# 109  2021A000011124  Tonnes   287.0         units        0.0  v1331406786
# 110  2021A000011124  Tonnes   287.0         units        0.0  v1331406711
# 111  2021A000011124  Tonnes   287.0         units        0.0  v1331406861
#
#     COORDINATE     VALUE STATUS  SYMBOL  TERMINATED  DECIMALS  \
# 0       1.7.12   43891.0    NaN     NaN         NaN       0.0
# 1       1.9.12   33699.0    NaN     NaN         NaN       0.0
# 2       1.8.12   10191.0    NaN     NaN         NaN       0.0
# 3       1.4.12    8863.0    NaN     NaN         NaN       0.0
# 4       1.2.12    7770.0    NaN     NaN         NaN       0.0
# ..         ...       ...    ...     ...         ...       ...
# 107    1.14.14    1114.0    NaN     NaN         NaN       0.0
# 108    1.11.14  720284.0    NaN     NaN         NaN       0.0
# 109    1.10.14    7276.0    NaN     NaN         NaN       0.0
# 110     1.5.14  732599.0    NaN     NaN         NaN       0.0
# 111    1.15.14  721398.0    NaN     NaN         NaN       0.0
#
#                           From                         To  Level_x  Level_y  \
# 0     Total discarded plastics                 Collection      2.0        2
# 1                   Collection    Total disposed plastics      2.0        2
# 2                   Collection          Material recovery      2.0        2
# 3               CA consumption  Net in-use stock addition      2.0        2
# 4    Net trade of new products             CA consumption      2.0        2
# ..                         ...                        ...      ...      ...
# 107                  Recycling    Total disposed plastics      2.0        2
# 108          Material recovery    Total disposed plastics      2.0        2
# 109          Material recovery                  Recycling      2.0        2
# 110             CA consumption   Total discarded plastics      2.0        2
# 111                        NaN                        NaN      2.0        2
#
#     Colour_HEX  Colour
# 0      #B91E32     red
# 1      #B91E32     red
# 2      #B91E32     red
# 3      #B91E32     red
# 4      #B91E32     red
# ..         ...     ...
# 107    #FDDA64  yellow
# 108    #FDDA64  yellow
# 109    #FDDA64  yellow
# 110    #FDDA64  yellow
# 111    #FDDA64  yellow
#
# [112 rows x 20 columns]

# %%
#reduce data frame to only 'VALUE', 'From', 'To', and 'Colour_HEX' that are needed for the Sankey
links = pd.DataFrame(df_StatCan_prod_2020_CA_2, columns=['VALUE','From','To','Colour_HEX'])

#remove rows where 'From' (and 'To') = "NaN"
links = links.dropna(subset=['From'])
links
# Out:
#         VALUE                       From                         To Colour_HEX
# 0     43891.0   Total discarded plastics                 Collection    #B91E32
# 1     33699.0                 Collection    Total disposed plastics    #B91E32
# 2     10191.0                 Collection          Material recovery    #B91E32
# 3      8863.0             CA consumption  Net in-use stock addition    #B91E32
# 4      7770.0  Net trade of new products             CA consumption    #B91E32
# ..        ...                        ...                        ...        ...
# 106    6161.0                  Recycling        Secondary feedstock    #FDDA64
# 107    1114.0                  Recycling    Total disposed plastics    #FDDA64
# 108  720284.0          Material recovery    Total disposed plastics    #FDDA64
# 109    7276.0          Material recovery                  Recycling    #FDDA64
# 110  732599.0             CA consumption   Total discarded plastics    #FDDA64
#
# [91 rows x 4 columns]

# %%
#create unique list of source/'From' and target/'To' for plotly
unique_from_to = list(pd.unique(links[['From','To']].values.ravel('K')))

# Create a list of unique nodes
unique_nodes = pd.concat([links['From'], links['To']]).unique()
node_index = {node: i for i, node in enumerate(unique_nodes)}

# Create new columns for indices in a safe way
links = links.assign(
    FromIndex=links['From'].map(node_index),
    ToIndex=links['To'].map(node_index))

#plot plotly Sankey
fig = go.Figure(data=[go.Sankey(
    valueformat = None,
    valuesuffix = 't', #all flows in unit tonnes
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(color = "black", width = 0.5),
      label = unique_from_to,
      color = "#7F7F7F"
    ),
    link = dict(
      source = links['FromIndex'], # indices correspond to labels
      target = links['ToIndex'],
      value = links['VALUE'],
        color = links['Colour_HEX']
  ))])

# Create legend
legend_trace = []
#creat two lists for legend of product categories and colour
categories= data_selection_StatCan_prod['Product category']
colors= data_selection_StatCan_prod['Colour_HEX']
#remove not-considered sub-categories of Electrical and electronic equipment (Electronics, Major appliances, Other electrical and electronic equipment)
#and of Packaging (Bottles, Film, Non-bottle rigid, Other packaging products)
    #remove index 3,4,5 and 7,8,9,10
categories= categories.drop([3,4,5,7,8,9,10])
colors= colors.drop([3,4,5,7,8,9,10])
for idx, (cat, color) in enumerate(zip(categories, colors)):
    legend_trace.append(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(size=10, color=color),
        name=cat
    ))

# Add legend to the figure
for trace in legend_trace:
    fig.add_trace(trace)

fig.update_layout(
    title_text="Sankey Diagram, PFAPM by product category, 2020, Canada", 
    font_size=10,
    font_color = "black",
    xaxis=dict(visible=False),
    yaxis=dict(visible=False),
    showlegend=True,
    legend=dict(
        title='Legend',
        orientation='h',
        yanchor='top',
        y=1.1,
        xanchor='right',
        x=0.9),
    width=1920,
    height=700,
    font=dict(size=16),
    plot_bgcolor='rgba(0,0,0,0)',     # Transparent plot area
    paper_bgcolor='rgba(0, 0, 0, 0)', # Transparent figure background
)
fig.show()
# Out:
# <div>                            <div id="cfa3c26e-a976-4d5a-9d40-576d45b1eb19" class="plotly-graph-div" style="height:700px; width:1920px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfa3c26e-a976-4d5a-9d40-576d45b1eb19")) {                    Plotly.newPlot(                        "cfa3c26e-a976-4d5a-9d40-576d45b1eb19",                        [{"link":{"color":["#B91E32","#B91E32","#B91E32","#B91E32","#B91E32","#B91E32","#B91E32","#B91E32","#B91E32","#B91E32","#B91E32","#B91E32","#B91E32","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#00A1C0","#FA961E","#FA961E","#FA961E","#FA961E","#FA961E","#FA961E","#FA961E","#FA961E","#FA961E","#FA961E","#FA961E","#FA961E","#FA961E","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#40E0FF","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#0BAC43","#005379","#005379","#005379","#005379","#005379","#005379","#005379","#005379","#005379","#005379","#7F7F7F","#7F7F7F","#7F7F7F","#FDDA64","#FDDA64","#FDDA64","#FDDA64","#FDDA64","#FDDA64","#FDDA64","#FDDA64","#FDDA64","#FDDA64","#FDDA64","#FDDA64","#FDDA64"],"source":[0,1,1,2,3,4,5,0,6,6,4,4,2,0,1,1,2,3,4,5,0,6,6,4,4,2,0,1,1,2,3,4,5,0,6,6,4,4,2,0,1,1,2,3,4,5,0,6,6,4,4,2,0,1,1,2,3,4,5,0,6,6,4,4,2,0,1,1,2,3,5,0,4,4,2,7,7,7,0,1,1,2,3,4,5,0,6,6,4,4,2],"target":[1,7,4,8,2,9,2,10,11,7,7,6,0,1,7,4,8,2,9,2,10,11,7,7,6,0,1,7,4,8,2,9,2,10,11,7,7,6,0,1,7,4,8,2,9,2,10,11,7,7,6,0,1,7,4,8,2,9,2,10,11,7,7,6,0,1,7,4,8,2,2,10,7,6,0,12,13,14,1,7,4,8,2,9,2,10,11,7,7,6,0],"value":[43891.0,33699.0,10191.0,8863.0,7770.0,0.0,45374.0,390.0,7185.0,1172.0,1834.0,8357.0,44281.0,164611.0,153304.0,11306.0,1380024.0,192863.0,5164.0,1353236.0,1463.0,3684.0,921.0,1537.0,9769.0,166074.0,439203.0,382850.0,56202.0,221161.0,514365.0,147.0,150005.0,4006.0,24193.0,5321.0,26835.0,29366.0,443209.0,1233538.0,1221946.0,10971.0,246672.0,600883.0,124.0,888604.0,9276.0,7520.0,2083.0,1492.0,9479.0,1242814.0,2000281.0,1569399.0,429986.0,149169.0,959097.0,4639.0,1208134.0,17781.0,313507.0,64180.0,56938.0,373048.0,2018063.0,278143.0,275362.0,2450.0,9834.0,221772.0,68678.0,2473.0,333.0,2116.0,280616.0,107577.0,3916862.0,496166.0,727622.0,0.0,727559.0,177688.0,149584.0,0.0,760703.0,4977.0,6161.0,1114.0,720284.0,7276.0,732599.0]},"node":{"color":"#7F7F7F","label":["Total discarded plastics","Collection","CA consumption","Net trade of new products","Material recovery","CA domestic production","Recycling","Total disposed plastics","Net in-use stock addition","Net trade baled plastic","Leak into environment","Secondary feedstock","Incineration (WtE) or gasification","Landfill or incineration","Net trade disposed plastics"],"line":{"color":"black","width":0.5},"pad":15,"thickness":20},"valuesuffix":"t","type":"sankey"},{"marker":{"color":"#7F7F7F","size":10},"mode":"markers","name":"Total, all product categories","x":[null],"y":[null],"type":"scatter"},{"marker":{"color":"#00A1C0","size":10},"mode":"markers","name":"Construction materials","x":[null],"y":[null],"type":"scatter"},{"marker":{"color":"#FA961E","size":10},"mode":"markers","name":"Electrical and electronic equipment","x":[null],"y":[null],"type":"scatter"},{"marker":{"color":"#0BAC43","size":10},"mode":"markers","name":"Packaging","x":[null],"y":[null],"type":"scatter"},{"marker":{"color":"#B91E32","size":10},"mode":"markers","name":"Agriculture film","x":[null],"y":[null],"type":"scatter"},{"marker":{"color":"#005379","size":10},"mode":"markers","name":"Textiles","x":[null],"y":[null],"type":"scatter"},{"marker":{"color":"#FDDA64","size":10},"mode":"markers","name":"Vehicles","x":[null],"y":[null],"type":"scatter"},{"marker":{"color":"#40E ...

# %%
#save figure in html format in files (or results or other) folder
fig.write_html("files/Sankey_prod_CA_2020.html")
